# %% [markdown]
# # zu ergänzen:
# ### Beschreibungen bei der Vektorisierung
# ### (T2S)
# ### Zusammenfassung und Ausblick
# # Grafiken:
# ### Agenda + Übersichten (erledigt)
# ### Sentiment-Analyse (erledigt)
# ### Skalierung der Grafiken
# ### Behebung von Darstellungsfehlern (erledigt)

# %% [markdown]
# # Natural Language Processing
# ![Was ist NLP](<https://s2.qwant.com/thumbr/0x380/c/e/10c54c87272bdae830c4378495ff38b0e0af52906cdb0b0f6836eb4ad110f0/NLP-word-cloud-e1432237783661.jpg?u=https%3A%2F%2Fwww.thoughtmodels.com%2Fwp-content%2Fuploads%2F2016%2F06%2FNLP-word-cloud-e1432237783661.jpg&q=0&b=1&p=0&a=1>)
#
#
# # Was ist Natural Language Processing?
#
# ### -eine mit der Computerlinguistik verwandte Disziplin
#
# ### -Verarbeitung natürlicher Sprache (gesprochen und als Text) durch Computer
#
# ### -Interaktion zwischen Mensch und Maschine auf der Basis menschlicher Sprache
#
# ### -Befähigt Software menschliche Sprache als Input zu erfassen und passende Ergebnisse als Output zur Verfügung zu stellen

# %% [markdown]
# ![Agenda](<./Grafiken/Agenda/Agenda.jpg>)

# %% [markdown]
# # Warum Natural Language Processing?
#
# -> Grafik Entwicklung des Anteils unstrukturierter Daten weltweit
#
# ### -Informationen und Inhalte werden direkt vom Kunden erstellt
#
# ### -Menschen unterschiedlicher Demographien, Regionen und Kulturen
#
# ### -nützlich bei der Erstellung von Kundenprofilen, sowie dem Erkennen von Trends und Entwicklungen

# %% [markdown]
# # Einsatz von Natural Language Processing
#
# ### Sprachassistenten
#
# ![Siri](<https://sophosnews.files.wordpress.com/2017/07/siri-1200.jpg?w=780&h=408&crop=1>)
#
# <img src=https://sophosnews.files.wordpress.com/2017/07/siri-1200.jpg?w=780&h=408&crop=1 width="500"/>
#
#
#
#
#
#
#
# ## bessere Übersetzungen dank des mit Einbeziehens von Grammatik und Semantik
#
# ![Google Tranlate](<http://icons.iconarchive.com/icons/marcus-roberto/google-play/256/Google-Translate-icon.png>)
#
#
#
#
#
#
#
# ## die "beliebten" Chatbots
#
# ![Chatbot](<https://mobilemonkey.com/wp-content/uploads/2017/04/efYxWC6.jpg>)

# %% [markdown]
# <img src=https://sophosnews.files.wordpress.com/2017/07/siri-1200.jpg?w=780&h=408&crop=1 width="500"/>

# %% [markdown]
# # Ein Anwendungsbeispiel: Named Entity Recognition
#
# ## Was ist Named Entity Recognition, bzw. "Eigennamenerkennung"?
# ### -automatische Identifikation und Klassifikation von Eigennamen
#
# ### -ein Eigenname beschreibt eine real existierende Identität
# ### -> Personen
# ### -> Organisationen
# ### -> Orte
# ### -> etc.

# %% [markdown]
# # Beispielsatz: Max Maier fährt mit seinem Auto zur TDWI nach München

# %%
import spacy
from spacy import displacy
import de_core_news_sm
nlp = de_core_news_sm.load()

text = 'Max Maier fährt mit dem Auto zur TDWI nach München.'

doc = nlp(text)

sentences = [x for x in doc.sents]

# %%
displacy.render(nlp(sentences[0].string), jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Max Maier
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  fährt mit dem Auto zur
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     TDWI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  nach
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     München
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# .</div>

# %%
displacy.render(nlp((sentences[0].string)), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="856-0" class="displacy" width="1250" height="317.0" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Max</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Maier</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">fährt</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">mit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">dem</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Auto</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">zur</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">TDWI</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">nach</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">München.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-856-0-0" stroke-width="2px" d="M70,182.0 C70,122.0 160.0,122.0 160.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-856-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">pnc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,184.0 L62,172.0 78,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-856-0-1" stroke-width="2px" d="M190,182.0 C190,122.0 280.0,122.0 280.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-856-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">sb</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,184.0 L182,172.0 198,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-856-0-2" stroke-width="2px" d="M310,182.0 C310,122.0 400.0,122.0 400.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-856-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">mo</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400.0,184.0 L408.0,172.0 392.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-856-0-3" stroke-width="2px" d="M550,182.0 C550,122.0 640.0,122.0 640.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-856-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">nk</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,184.0 L542,172.0 558,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-856-0-4" stroke-width="2px" d="M430,182.0 C430,62.0 645.0,62.0 645.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-856-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">nk</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M645.0,184.0 L653.0,172.0 637.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-856-0-5" stroke-width="2px" d="M310,182.0 C310,2.0 770.0,2.0 770.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-856-0-5" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">mo</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770.0,184.0 L778.0,172.0 762.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-856-0-6" stroke-width="2px" d="M790,182.0 C790,122.0 880.0,122.0 880.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-856-0-6" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">nk</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M880.0,184.0 L888.0,172.0 872.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-856-0-7" stroke-width="2px" d="M910,182.0 C910,122.0 1000.0,122.0 1000.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-856-0-7" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">mnr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1000.0,184.0 L1008.0,172.0 992.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-856-0-8" stroke-width="2px" d="M1030,182.0 C1030,122.0 1120.0,122.0 1120.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-856-0-8" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">nk</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120.0,184.0 L1128.0,172.0 1112.0,172.0" fill="currentColor"/>
# </g>
# </svg>

# %% [markdown]
# # Anwendungsmöglichkeiten?
#
# -> z.B. zur Anonymisierung von Personen in Texten
#
#
# ![Named Entity Recognition](<./Grafiken/NaturalEntityRecognition.jpg>)

# %%
text = 'Max Maier fährt mit dem Auto zur TDWI nach München.'

doc = nlp(text)

typeList = []
censored = []
for word in doc:
    if word.ent_type_ == 'PER' and len(word) > 1:
        cens = 'X'*5
        censored.append(cens)
    else:
        censored.append(word.text)

# %%
str(censored)
# Out:
# "['XXXXX', 'XXXXX', 'fährt', 'mit', 'dem', 'Auto', 'zur', 'TDWI', 'nach', 'München', '.']"

# %% [markdown]
# ![Normalisierung](<./Grafiken/Agenda/Normalisierung.jpg>)

# %% [markdown]
# # Text-Normalisierung

# %%
def read_documents(fqn :str):
    import glob, os
    documents = {}
    
    for file in glob.glob(fqn):

        filename = open(file, "r", encoding='cp1252')
        text = str(filename.readlines())

        path = os.path.basename(file)
        extension = os.path.splitext(file)[1]
        filename, extension = path.split('.')

        documents[filename] = text
            
    return(documents)

# %%
documents = read_documents("./Artikel/*.txt")

# %%
Dokument_1 = 'Das Auto fährt schnell. Ein Auto ist kein Motorrad.'
Dokument_2 = 'Der Zug fährt schneller als das Auto'
Dokument_3 = 'Ein Flugzeug fliegt'

beispiel = {}
beispiel['Dokument_1'] = Dokument_1
beispiel['Dokument_2'] = Dokument_2
beispiel['Dokument_3'] = Dokument_3

# %% [markdown]
# # Tokenisierung
#
# ### Worte sind die kleinste Informationstragende Einheit in Sprachen
# ### Tokenisierung bedeutet die Zerlegung von Text in einzelne Worte, bzw. "Token"
# ### Üblicherweise der erste Schritt um Zugang zu der im Text enthaltenen Information zu erlangen
#
# ### ABER:
# ### -Satzstrukturen gehen verloren
# ### -daher nicht für semantische Analysen wie Named Entity Recognition geeignet

# %% [markdown]
# ### ein einfaches Beispiel:
#
# 'Das Auto fährt schnell. Ein Auto ist kein Motorrad.'

# %%
beispiel.get('Dokument_1').split(' ')
# Out:
# ['Das', 'Auto', 'fährt', 'schnell.', 'Ein', 'Auto', 'ist', 'kein', 'Motorrad.']

# %% [markdown]
# ### ein einfaches "Zerteilen" des Satzes ist nicht ausreichend:
# ### -Satzzeichen werden nicht von Worten getrennt: 'Angebot.'
# ### -Zeilenumbrüche werden nicht ignoriert:  "\n',", "Euro.\\n'

# %% [markdown]
# ## Beispiel eines simplen Tokenizers:

# %%
def tokenizer(documents):
    tokenized = {}
    
    for doc in documents:
        
        document = documents.get(doc)
        punctuations = ['(',')',';',':','[',']','{','}',',','.','-','``',"''",'!','\"','§','$','%','&','?','@','+','–','~','*','#','\'','\\n','\\','„','“']
        cleaned = []

        token = document.split(' ')

        for t in token:
            temp = t
            for p in punctuations:
                if p in t:
                    temp = temp.replace(p, '')
            cleaned.append(temp.lower())
            
        tokenized[doc] = cleaned
        #bei kMeans: str(cleaned)

    return(tokenized)

# %%
tokenized = tokenizer(documents)
beispiel_tokenized = tokenizer(beispiel)
beispiel_tokenized
# Out:
# {'Dokument_1': ['das',
#   'auto',
#   'fährt',
#   'schnell',
#   'ein',
#   'auto',
#   'ist',
#   'kein',
#   'motorrad'],
#  'Dokument_2': ['der', 'zug', 'fährt', 'schneller', 'als', 'das', 'auto'],
#  'Dokument_3': ['ein', 'flugzeug', 'fliegt']}

# %% [markdown]
# ## Stopwords
#
# ### Stopwords sind Worte welche häufig vorkommen, meist jedoch wenig an benötigter Information enthalten
# ### -Bspw.: der, die, das, dem, dessen, etc.
# ### -Aussortieren, um größe des Datensatzes zu reduzieren und eine mögliche Überlagerung der eigentlich interessanten Information zu verhindern
# ### -es sind auch sogenannte Startwords möglich, mit deren Hilfe schnell und einfach untersucht werden kann, ob ein Text thematisch überhaupt interessant ist

# %% [markdown]
# ## Beispiel Stopwords:

# %%
def stopwords(tokenized):
    stopwords = ["ab","aber","ach","acht","achte","achten","achter","achtes","ag","alle","allein","allem","allen","aller","allerdings","alles","allgemeinen","als","also","am","an","ander","andere","anderem","anderen","anderer","anderes","anderm","andern","anderr","anders","au","auch","auf","aus","ausser","ausserdem","außer","außerdem","b","bald","bei","beide","beiden","beim","beispiel","bekannt","bereits","besonders","besser","besten","bin","bis","bisher","bist","c","d","d.h","da","dabei","dadurch","dafür","dagegen","daher","dahin","dahinter","damals","damit","danach","daneben","dank","dann","daran","darauf","daraus","darf","darfst","darin","darum","darunter","darüber","das","dasein","daselbst","dass","dasselbe","davon","davor","dazu","dazwischen","daß","dein","deine","deinem","deinen","deiner","deines","dem","dementsprechend","demgegenüber","demgemäss","demgemäß","demselben","demzufolge","den","denen","denn","denselben","der","deren","derer","derjenige","derjenigen","dermassen","dermaßen","derselbe","derselben","des","deshalb","desselben","dessen","deswegen","dich","die","diejenige","diejenigen","dies","diese","dieselbe","dieselben","diesem","diesen","dieser","dieses","dir","doch","dort","drei","drin","dritte","dritten","dritter","drittes","du","durch","durchaus","durfte","durften","dürfen","dürft","e","eben","ebenso","ehrlich","ei","ei,","eigen","eigene","eigenen","eigener","eigenes","ein","einander","eine","einem","einen","einer","eines","einig","einige","einigem","einigen","einiger","einiges","einmal","eins","elf","en","ende","endlich","entweder","er","ernst","erst","erste","ersten","erster","erstes","es","etwa","etwas","euch","euer","eure","eurem","euren","eurer","eures","f","folgende","früher","fünf","fünfte","fünften","fünfter","fünftes","für","g","gab","ganz","ganze","ganzen","ganzer","ganzes","gar","gedurft","gegen","gegenüber","gehabt","gehen","geht","gekannt","gekonnt","gemacht","gemocht","gemusst","genug","gerade","gern","gesagt","geschweige","gewesen","gewollt","geworden","gibt","ging","gleich","gott","gross","grosse","grossen","grosser","grosses","groß","große","großen","großer","großes","gut","gute","guter","gutes","h","hab","habe","haben","habt","hast","hat","hatte","hatten","hattest","hattet","heisst","her","heute","hier","hin","hinter","hoch","hätte","hätten","i","ich","ihm","ihn","ihnen","ihr","ihre","ihrem","ihren","ihrer","ihres","im","immer","in","indem","infolgedessen","ins","irgend","ist","j","ja","jahr","jahre","jahren","je","jede","jedem","jeden","jeder","jedermann","jedermanns","jedes","jedoch","jemand","jemandem","jemanden","jene","jenem","jenen","jener","jenes","jetzt","k","kam","kann","kannst","kaum","kein","keine","keinem","keinen","keiner","keines","kleine","kleinen","kleiner","kleines","kommen","kommt","konnte","konnten","kurz","können","könnt","könnte","l","lang","lange","leicht","leide","lieber","los","m","machen","macht","machte","mag","magst","mahn","mal","man","manche","manchem","manchen","mancher","manches","mann","mehr","mein","meine","meinem","meinen","meiner","meines","mensch","menschen","mich","mir","mit","mittel","mochte","mochten","morgen","muss","musst","musste","mussten","muß","mußt","möchte","mögen","möglich","mögt","müssen","müsst","müßt","n","na","nach","nachdem","nahm","natürlich","neben","nein","neue","neuen","neun","neunte","neunten","neunter","neuntes","nicht","nichts","nie","niemand","niemandem","niemanden","noch","nun","nur","o","ob","oben","oder","offen","oft","ohne","ordnung","p","q","r","recht","rechte","rechten","rechter","rechtes","richtig","rund","s","sa","sache","sagt","sagte","sah","satt","schlecht","schluss","schon","sechs","sechste","sechsten","sechster","sechstes","sehr","sei","seid","seien","sein","seine","seinem","seinen","seiner","seines","seit","seitdem","selbst","sich","sie","sieben","siebente","siebenten","siebenter","siebentes","sind","so","solang","solche","solchem","solchen","solcher","solches","soll","sollen","sollst","sollt","sollte","sollten","sondern","sonst","soweit","sowie","später","startseite","statt","steht","suche","t","tag","tage","tagen","tat","teil","tel","tritt","trotzdem","tun","u","uhr","um","und","und?","uns","unse","unsem","unsen","unser","unsere","unserer","unses","unter","v","vergangenen","viel","viele","vielem","vielen","vielleicht","vier","vierte","vierten","vierter","viertes","vom","von","vor","w","wahr?","wann","war","waren","warst","wart","warum","was","weg","wegen","weil","weit","weiter","weitere","weiteren","weiteres","welche","welchem","welchen","welcher","welches","wem","wen","wenig","wenige","weniger","weniges","wenigstens","wenn","wer","werde","werden","werdet","weshalb","wessen","wie","wieder","wieso","will","willst","wir","wird","wirklich","wirst","wissen","wo","woher","wohin","wohl","wollen","wollt","wollte","wollten","worden","wurde","wurden","während","währenddem","währenddessen","wäre","würde","würden","x","y","z","z.b","zehn","zehnte","zehnten","zehnter","zehntes","zeit","zu","zuerst","zugleich","zum","zunächst","zur","zurück","zusammen","zwanzig","zwar","zwei","zweite","zweiten","zweiter","zweites","zwischen","zwölf","über","überhaupt","übrigens"]
    
    removed = {}
    
    for doc in tokenized:
        document = tokenized.get(doc)
        no_stopwords = [token for token in document if not token in stopwords]
        removed[doc] = no_stopwords
    
    return(removed)

# %%
stopwordsRemoved = stopwords(tokenized)

beispiel_stopwords = stopwords(beispiel_tokenized)
beispiel_stopwords
# Out:
# {'Dokument_1': ['auto', 'fährt', 'schnell', 'auto', 'motorrad'],
#  'Dokument_2': ['zug', 'fährt', 'schneller', 'auto'],
#  'Dokument_3': ['flugzeug', 'fliegt']}

# %% [markdown]
# ![Sentiment](<./Grafiken/Agenda/Sentiment.jpg>)

# %% [markdown]
# # Sentiment Analysis
#
# ### Sentiment = Gefühl, Empfindung
# ### Möglichkeit um die "Stimmung" oder "Gefühlslage" in einem Text zu analysieren
#
# ### Anwendung bspw. als Ergänzung zur Analyse der Stimmung von Investoren oder im Marketing

# %% [markdown]
# ## Funktionsweise:
#
# ### -Worte werden als positive oder negative Signale festgelegt
# ### -Bspw. "stark", "gut", "schnell" als positive, oder "schwach", "schlecht", "langsam" als negative
# ### -Überprüfung des Verhältnisses, in welchem positive und negative Worte in einem Text vorkommen

# %% [markdown]
# ![Sentiment-Analyse](<./Grafiken/Sentiment_Analysis.jpg>)

# %% [markdown]
# ## Anwendungsbeispiel:

# %%
def sentimentAnalysis(documents):
    import json
    with open('./SentimentAnalysis/positive.json') as positive:  
        positiveWords = json.load(positive)
    with open('./SentimentAnalysis/negative.json') as negative:  
        negativeWords = json.load(negative)
    
    for doc in documents:
        positive = 0
        negative = 0
        text = documents.get(doc)
        summe = len(text)
        for token in text:
            if token in positiveWords:
                positive += 1
            elif token in negativeWords:
                negative += 1
        if positive > negative:
            print("Der Artikel '" + doc + "' ist überwiegend positiv (" + str(round((positive/summe)*100, 2)) + "%)")
        elif negative > positive:
            print("Der Artikel '" + doc + "' ist überwiegend negativ (" + str(round((negative/summe)*100, 2)) + "%)")
        elif positive == negative:
            print("Der Artikel '" + doc + "' ist neutral")
        print('_'*150)
        print(' ')

# %%
sentimentAnalysis(stopwordsRemoved)
# Out:
# Der Artikel 'Zweite Bundesliga' ist überwiegend negativ (4.95%)
# ______________________________________________________________________________________________________________________________________________________
#
# Der Artikel 'Joachim Löw und die Nationalelf' ist überwiegend positiv (1.24%)
# ______________________________________________________________________________________________________________________________________________________
#
# Der Artikel 'Konkurrenz für Netflix' ist überwiegend positiv (4.35%)
# ______________________________________________________________________________________________________________________________________________________
#
# Der Artikel 'Blitz und Schatten' ist überwiegend positiv (6.17%)
# ______________________________________________________________________________________________________________________________________________________
#
# Der Artikel 'Ladematte AirPower' ist überwiegend negativ (6.09%)
# ______________________________________________________________________________________________________________________________________________________
#
# Der Artikel 'Weißes Haus rechnet mit Schließung der Grenze zu Mexiko' ist überwiegend positiv (3.7%)
# ______________________________________________________________________________________________________________________________________________________
#
# Der Artikel 'Was Kim kann, kann Trump auch' ist überwiegend positiv (3.7%)
# ______________________________________________________________________________________________________________________________________________________
#
# Der Artikel 'Dramatischer Liverpool-Sieg durch spätes Eigentor' ist überwiegend positiv (5.75%)
# ______________________________________________________________________________________________________________________________________________________
#
# Der Artikel 'Hollywood-Stars präsentieren' ist überwiegend positiv (4.52%)
# ______________________________________________________________________________________________________________________________________________________
#
# Der Artikel 'Tesla im Fahrtest' ist überwiegend positiv (4.51%)
# ______________________________________________________________________________________________________________________________________________________
#
# Der Artikel 'Lebensrettende Massnahmen für Apple TV' ist überwiegend positiv (3.57%)
# ______________________________________________________________________________________________________________________________________________________
#
# Der Artikel 'Der Vorwurf eines unerwünschten Kusses' ist neutral
# ______________________________________________________________________________________________________________________________________________________
#
# Der Artikel 'Natixis im Gespräch' ist überwiegend positiv (5.43%)
# ______________________________________________________________________________________________________________________________________________________
#
# Der Artikel 'Mittelklasse, nur nicht beim Preis' ist überwiegend positiv (4.27%)
# ______________________________________________________________________________________________________________________________________________________
#
# Der Artikel 'Bleibt doch noch ein bisschen' ist überwiegend positiv (5.71%)
# ______________________________________________________________________________________________________________________________________________________
#
# Der Artikel 'Der Brandbeschleuniger im Weißen Haus' ist neutral
# ______________________________________________________________________________________________________________________________________________________
#
# Der Artikel 'Schweizer Banken Die Zeiten, um an den Finanzmärkten mutig zu sein, sind erst einmal vorbei' ist überwiegend positiv (7.2%)
# ______________________________________________________________________________________________________________________________________________________
#
# Der Artikel 'Bankenmarkt' ist überwiegend positiv (4.46%)
# ______________________________________________________________________________________________________________________________________________________
#
# Der Artikel 'Deutschland sucht das Super-SUV' ist überwiegend positiv (4.75%)
# ______________________________________________________________________________________________________________________________________________________
#
# Der Artikel 'Die Mailänder Börse ist in Feierlaune' ist überwiegend positiv (2.21%)
# ______________________________________________________________________________________________________________________________________________________
#
# Der Artikel 'Trump, Trump und nochmals Trump' ist überwiegend negativ (4.78%)
# ______________________________________________________________________________________________________________________________________________________
#
# Der Artikel 'Basel IV' ist überwiegend positiv (3.01%)
# ______________________________________________________________________________________________________________________________________________________
#
# Der Artikel 'Jetzt wird Bayern nervös' ist überwiegend positiv (3.9%)
# ______________________________________________________________________________________________________________________________________________________
#
# Der Artikel 'BMW setzt noch einen drauf' ist überwiegend positiv (4.63%)
# ______________________________________________________________________________________________________________________________________________________
#
# Der Artikel 'Klopp geht all in und gewinnt' ist überwiegend positiv (3.85%)
# ______________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## Ergebnisse im Detail:

# %% [markdown]
# ## Der Artikel 'BMW setzt noch einen drauf' ist überwiegend positiv (4.63%)
#
# ## positiv:
# ['mächtige', 'wagte', 'stattliche', 'großem', 'wert', 'erneuerten', 'verantwortlichen', 'starkes', 'maximale', 'verstärkungen', 'spezielle',
#
# ## negativ:
# ['beeindruckte', 'ruhe', 'schlechter']
#
#
#
# ## Der Artikel 'Der Vorwurf eines unerwünschten Kusses' ist neutral
#
# ## positiv:
# ['mögliche', 'mögliche', 'erklärte', 'sicher']
#
# ## negativ:
# ['vorwürfe', 'vorwürfe', 'vorwürfen', 'unangemessenes']
#
#
#
# ## Der Artikel 'Trump, Trump und nochmals Trump' ist überwiegend negativ (4,78%)
#
# ## positiv:
# ['gewinnen', 'möglichst', 'kommunikativen', 'gepflegtere', 'wiederherstellung', 'guten', 'gelassene', 'möglichst']
#
# ## negativ:
# ['schelten', 'unzufriedenen', 'tote', 'bizarre', 'sorgen', 'attacken', 'kriminelle', 'schwerer', 'drastische', 'bitterer', 'blutigen']

# %% [markdown]
# ![Vektorisierung](<./Grafiken/Agenda/Vektorisierung.jpg>)

# %% [markdown]
# # Vektorisierung

# %% [markdown]
# ## Herausforderungen
#
# ## Typischerweise werden durch Algorithmen strukturierte, numerische Daten analysiert
#
# ![Datenanalyse](<./Grafiken/Netzwerk_Daten.jpg>)

# %% [markdown]
# ## Was sind strukturierte Daten?

# %%
Attribut_1 = ['X','X','X']
Attribut_2 = ['X','X','X']
Attribut_3 = ['X','X','X']

array = {}
array['Attribut_1'] = Attribut_1
array['Attribut_2'] = Attribut_2
array['Attribut_3'] = Attribut_3

import pandas as pd
Dataframe = pd.DataFrame.from_dict(array)
Dataframe
# Out:
#   Attribut_1 Attribut_2 Attribut_3
# 0          X          X          X
# 1          X          X          X
# 2          X          X          X

# %%
Länge = [3,5,8]
Breite = [9,7,3]
Höhe = [4,2,7]

maßearray = {}
maßearray['Länge'] = Länge
maßearray['Breite'] = Breite
maßearray['Höhe'] = Höhe

import pandas as pd
MaßeDataframe = pd.DataFrame.from_dict(maßearray)
MaßeDataframe
# Out:
#    Länge  Breite  Höhe
# 0      3       9     4
# 1      5       7     2
# 2      8       3     7

# %%
Haus = ['groß', 'breit', 'neu']
Auto = ['schnell', 'BMW', 'Porsche']
Flugzeug = ['Triebwerk', 'Airbus', 'fliegt']

wortearray = {}
wortearray['Haus'] = Haus
wortearray['Auto'] = Auto
wortearray['Flugzeug'] = Flugzeug
WorteDataframe = pd.DataFrame.from_dict(wortearray)
WorteDataframe
# Out:
#     Haus     Auto   Flugzeug
# 0   groß  schnell  Triebwerk
# 1  breit      BMW     Airbus
# 2    neu  Porsche     fliegt

# %% [markdown]
# ## Bildung des Vokabulars
# ### -enthält jedes im Dokument, bzw. Dokumenten-Korpus, vorkommende Wort (Token) genau einmal
# ### -ein Token ist ein Attribut

# %%
beispiel_stopwords
# Out:
# {'Dokument_1': ['auto', 'fährt', 'schnell', 'auto', 'motorrad'],
#  'Dokument_2': ['zug', 'fährt', 'schneller', 'auto'],
#  'Dokument_3': ['flugzeug', 'fliegt']}

# %% [markdown]
# ### für das Vokabular folgt:
# ## Vokabular = ['auto', fliegt', 'flugzeug', 'fährt', 'motorrad', 'schnell', 'schneller', 'zug']

# %%
def get_vocabulary(documents):
    vocabulary = set()

    for key in documents:
        text = documents.get(key)
        vocabulary = vocabulary.union(text)
    
    return(vocabulary)

# %%
beispiel_vocabulary = get_vocabulary(beispiel_stopwords)
str(beispiel_vocabulary)
# Out:
# "{'auto', 'schneller', 'zug', 'fährt', 'schnell', 'flugzeug', 'fliegt', 'motorrad'}"

# %% [markdown]
# ### Überführung in einen Vektorraum
# ## $VR=\{W_1,W_2,\dots,W_N\}$

# %%
data = [('W_11', 'W_12', 'W_13', 'W_14', 'W_15', 'W_16', 'W_17', 'W_18'), ('W_21', 'W_22', 'W_23', 'W_24', 'W_25', 'W_26', 'W_27', 'W_28'), ('W_31', 'W_32', 'W_33', 'W_34', 'W_35', 'W_36', 'W_37', 'W_38')]
df = pd.DataFrame(data, columns=beispiel_vocabulary, index=['Dokument_1', 'Dokument_2', 'Dokument_3'])
df
# Out:
#             auto schneller   zug fährt schnell flugzeug fliegt motorrad
# Dokument_1  W_11      W_12  W_13  W_14    W_15     W_16   W_17     W_18
# Dokument_2  W_21      W_22  W_23  W_24    W_25     W_26   W_27     W_28
# Dokument_3  W_31      W_32  W_33  W_34    W_35     W_36   W_37     W_38

# %% [raw]
# ### Wo bin ich Übersicht
#
#
# --- Was mache ich warum wann?
#  --- SAS Skipt hat hier eine Tabelle ----
#
# - Entropie
# - Mutual Information (wenn zeit ist ggf. kann ich das machen)
# - bag of words
# - term_frequency

# %% [markdown]
# ## Bag-of-Words
#
# ### -einfacher Ansatz in welchem ein Dokument als ein "Bag" aus Worten (unabhängig von Folgen und Grammatik) repräsentiert wird
# ### -die Gewichtung eines Wortes basiert auf der absoluten Häufigkeit, mit welcher es im Dokument vorkommt

# %%
def bag_of_words(documents, vocabulary):
    import pandas as pd
    bow = {}
    
    for key in documents:
        document = documents.get(key)
        dictTemp = dict.fromkeys(vocabulary, 0)

        for token in document:
            dictTemp[token]+=1
        
        bow[key] = dictTemp
    
    bowDF = pd.DataFrame(bow).T
        
    return(bow, bowDF)

# %%
beispiel_bow, beispiel_bowDF = bag_of_words(beispiel_stopwords, beispiel_vocabulary)
beispiel_bowDF
# Out:
#             auto  fliegt  flugzeug  fährt  motorrad  schnell  schneller  zug
# Dokument_1     2       0         0      1         1        1          0    0
# Dokument_2     1       0         0      1         0        0          1    1
# Dokument_3     0       1         1      0         0        0          0    0

# %%
from matplotlib import pyplot as plt
pd.plotting.parallel_coordinates(beispiel_bowDF, 'auto', color=('#556270', '#4ECDC4', '#C7F464'))
plt.show()

# %%
from pandas.tools.plotting import parallel_coordinates
import seaborn as sns
parallel_coordinates(beispiel_bowDF, 'auto', colormap=plt.get_cmap("Set2"))
plt.show()
# Out:
# /home/stephan/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: 'pandas.tools.plotting.parallel_coordinates' is deprecated, import 'pandas.plotting.parallel_coordinates' instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ## Term Frequency - Inverse Document Frequency (TF-IDF)
#
# ### -Beurteilung der Relevanz von Worten innerhalb eines Dokumenten-Korpus
# ### -Relevanz eines Wortes innerhalb eines Dokuments

# %% [markdown]
# ### Term Frequency
#
# ### $tf(w,D) = f_{W_D}$

# %%
def term_frequency(bow, documents):
    import pandas as pd
    tfDict= {}
    
    for key in documents:
        tfCount = {}
        doc = documents.get(key)
        wordCount = len(doc)
        for word, count in bow.get(key).items():
            tfCount[word] = count / float(wordCount)
            
        tfDict[key] = tfCount
        
    tfDF = pd.DataFrame(tfDict).T
        
    return(tfDict, tfDF)

# %%
beispiel_tf, beispiel_tfDF = term_frequency(beispiel_bow, beispiel_stopwords)
beispiel_tfDF
# Out:
#             auto  fliegt  flugzeug  fährt  motorrad  schnell  schneller   zug
# Dokument_1  0.40     0.0       0.0   0.20       0.2      0.2       0.00  0.00
# Dokument_2  0.25     0.0       0.0   0.25       0.0      0.0       0.25  0.25
# Dokument_3  0.00     0.5       0.5   0.00       0.0      0.0       0.00  0.00

# %% [markdown]
# ### Inverse Document Frequency
#
# ### -inverse Dokumentenhäufigkeit
# ### -Aussage über die Spezifität eines Wortes innerhalb eines Dokumenten-Korpus
#
# ### $idf(t) = \log \frac{C}{\sum{df(t)}}$
#
# ### $C=$ Anzahl der Dokumente innerhalb des Korpus
# ### $df(t)=$ Anzahl der Dokumente, welche einen spezifischen Term enthalten

# %%
def inverse_document_frequency(bow):
    import math
    idfDict = {}
    N = len(bow)
    idfDict = dict.fromkeys(bow[next(iter(bow))].keys(),0)
    i = 0
    for key in bow:
        doc = bow.get(key)
        for word, val in doc.items():
            if val > 0:
                idfDict[word] +=1
        i = i + 1
    for word, val in idfDict.items():
        idfDict[word]= math.log(N / float(val))
    
    return(idfDict)

# %%
beispiel_idf = inverse_document_frequency(beispiel_bow)
beispiel_idf
# Out:
# {'auto': 0.4054651081081644,
#  'schneller': 1.0986122886681098,
#  'zug': 1.0986122886681098,
#  'fährt': 0.4054651081081644,
#  'schnell': 1.0986122886681098,
#  'flugzeug': 1.0986122886681098,
#  'fliegt': 1.0986122886681098,
#  'motorrad': 1.0986122886681098}

# %% [markdown]
# ## TF-IDF
#
# $tfidf=tf\times idf$

# %%
def term_frequency_inverse_document_frequency(tfBow, idfs):
    import pandas as pd
    tfidf = {}
    tfidfDict = {}
    for key in tfBow:
        text = tfBow.get(key)
        tfidf = {}
        for word, val in text.items():
            tfidf[word] = val * idfs[word]
        tfidfDict[key] = tfidf
    
    tfidfDF = pd.DataFrame(tfidfDict).T
    
    return(tfidfDict, tfidfDF)

# %%
beispiel_tfidf, beispiel_tfidfDF = term_frequency_inverse_document_frequency(beispiel_bow, beispiel_idf)
beispiel_tfidfDF
# Out:
#                 auto    fliegt  flugzeug     fährt  motorrad   schnell  \
# Dokument_1  0.810930  0.000000  0.000000  0.405465  1.098612  1.098612
# Dokument_2  0.405465  0.000000  0.000000  0.405465  0.000000  0.000000
# Dokument_3  0.000000  1.098612  1.098612  0.000000  0.000000  0.000000
#
#             schneller       zug
# Dokument_1   0.000000  0.000000
# Dokument_2   1.098612  1.098612
# Dokument_3   0.000000  0.000000

# %%
from matplotlib import pyplot as plt
pd.plotting.parallel_coordinates(beispiel_tfidfDF, 'auto', color=('#556270', '#4ECDC4', '#C7F464'))
plt.show()

# %%
vocabulary = get_vocabulary(stopwordsRemoved)
bow, bowDF = bag_of_words(stopwordsRemoved, vocabulary)
tf, tfDF = term_frequency(bow, stopwordsRemoved)
idf = inverse_document_frequency(bow)
tfidf, tfidfDF = term_frequency_inverse_document_frequency(bow, idf)

# %%
tfidfDF
# Out:
#                                                                00       000  \
# Zweite Bundesliga                                   0.0  3.218876  0.000000
# Joachim Löw und die Nationalelf                     0.0  0.000000  0.000000
# Konkurrenz für Netflix                              0.0  0.000000  0.000000
# Blitz und Schatten                                  0.0  0.000000  0.000000
# Ladematte AirPower                                  0.0  0.000000  0.000000
# Weißes Haus rechnet mit Schließung der Grenze z...  0.0  0.000000  1.832581
# Was Kim kann, kann Trump auch                       0.0  0.000000  0.000000
# Dramatischer Liverpool-Sieg durch spätes Eigentor   0.0  0.000000  0.000000
# Hollywood-Stars präsentieren                        0.0  0.000000  0.000000
# Tesla im Fahrtest                                   0.0  0.000000  3.665163
# Lebensrettende Massnahmen für Apple TV              0.0  0.000000  0.000000
# Der Vorwurf eines unerwünschten Kusses              0.0  0.000000  0.000000
# Natixis im Gespräch                                 0.0  0.000000  0.000000
# Mittelklasse, nur nicht beim Preis                  0.0  0.000000  3.665163
# Bleibt doch noch ein bisschen                       0.0  0.000000  0.000000
# Der Brandbeschleuniger im Weißen Haus               0.0  0.000000  0.000000
# Schweizer Banken Die Zeiten, um an den Finanzmä...  0.0  0.000000  0.000000
# Bankenmarkt                                         0.0  0.000000  0.000000
# Deutschland sucht das Super-SUV                     0.0  0.000000  0.000000
# Die Mailänder Börse ist in Feierlaune               0.0  0.000000  0.000000
# Trump, Trump und nochmals Trump                     0.0  0.000000  0.000000
# Basel IV                                            0.0  0.000000  0.000000
# Jetzt wird Bayern nervös                            0.0  0.000000  0.000000
# BMW setzt noch einen drauf                          0.0  0.000000  0.000000
# Klopp geht all in und gewinnt                       0.0  0.000000  1.832581
#
#                                                           02        03  \
# Zweite Bundesliga                                   0.000000  0.000000
# Joachim Löw und die Nationalelf                     2.525729  3.218876
# Konkurrenz für Netflix                              0.000000  0.000000
# Blitz und Schatten                                  0.000000  0.000000
# Ladematte AirPower                                  0.000000  0.000000
# Weißes Haus rechnet mit Schließung der Grenze z...  0.000000  0.000000
# Was Kim kann, kann Trump auch                       0.000000  0.000000
# Dramatischer Liverpool-Sieg durch spätes Eigentor   5.051457  0.000000
# Hollywood-Stars präsentieren                        0.000000  0.000000
# Tesla im Fahrtest                                   0.000000  0.000000
# Lebensrettende Massnahmen für Apple TV              0.000000  0.000000
# Der Vorwurf eines unerwünschten Kusses              0.000000  0.000000
# Natixis im Gespräch                                 0.000000  0.000000
# Mittelklasse, nur nicht beim Preis                  0.000000  0.000000
# Bleibt doch noch ein bisschen                       0.000000  0.000000
# Der Brandbeschleuniger im Weißen Haus               0.000000  0.000000
# Schweizer Banken Die Zeiten, um an den Finanzmä...  0.000000  0.000000
# Bankenmarkt                                         0.000000  0.000000
# Deutschland sucht das Super-SUV                     0.000000  0.000000
# Die Mailänder Börse ist in Feierlaune               0.000000  0.000000
# Trump, Trump und nochmals Trump                     0.000000  0.000000
# Basel IV                                            0.000000  0.000000
# Jetzt wird Bayern nervös                            0.000000  0.000000
# BMW setzt noch einen drauf                          0.000000  0.000000
# Klopp geht all in und gewinnt                       0.000000  0.000000
#
#                                                           10       100  \
# Zweite Bundesliga                                   0.000000  0.000000
# Joachim Löw und die Nationalelf                     1.609438  0.000000
# Konkurrenz für Netflix                              0.000000  0.000000
# Blitz und Schatten                                  0.000000  0.000000
# Ladematte AirPower                                  0.000000  0.000000
# Weißes Haus rechnet mit Schließung der Grenze z...  0.000000  2.120264
# Was Kim kann, kann Trump auch                       0.000000  0.000000
# Dramatischer Liverpool-Sieg durch spätes Eigentor   3.218876  0.000000
# Hollywood-Stars präsentieren                        0.000000  2.120264
# Tesla im Fahrtest                                   0.000000  0.000000
# Lebensrettende Massnahmen für Apple TV              0.000000  0.000000
# Der Vorwurf eines unerwünschten Kusses              0.000000  0.000000
# Natixis im Gespräch                                 0.000000  0.000000
# Mittelklasse, nur nicht beim Preis                  0.000000  0.000000
# Bleibt doch noch ein bisschen                       0.000000  0.000000
# Der Brandbeschleuniger im Weißen Haus               0.000000  0.000000
# Schweizer Banken Die Zeiten, um an den Finanzmä...  1.609438  0.000000
# Bankenmarkt                                         0.000000  0.000000
# Deutschland sucht das Super-SUV                     1.609438  4.240527
# Die Mailänder Börse ist in Feierlaune               0.000000  0.000000
# Trump, Trump und nochmals Trump                     0.000000  0.000000
# Basel IV                                            0.000000  0.000000
# Jetzt wird Bayern nervös                            1.609438  0.000000
# BMW setzt noch einen drauf                          0.000000  0.000000
# Klopp geht all in und gewinnt                       0.000000  0.000000
#
#                                                        10000       105  \
# Zweite Bundesliga                                   0.000000  0.000000
# Joachim Löw und die Nationalelf                     0.000000  0.000000
# Konkurrenz für Netflix                              0.000000  0.000000
# Blitz und Schatten                                  0.000000  0.000000
# Ladematte AirPower                                  0.000000  0.000000
# Weißes Haus rechnet mit Schließung der Grenze z...  0.000000  0.000000
# Was Kim kann, kann Trump auch                       0.000000  0.000000
# Dramatischer Liverpool-Sieg durch spätes Eigentor   0.000000  0.000000
# Hollywood-Stars präsentieren                        0.000000  0.000000
# Tesla im Fahrtest                                   0.000000  0.000000
# Lebensrettende Massnahmen für Apple TV              0.000000  0.000000
# Der Vorwurf eines unerwünschten Kusses              0.000000  0.000000
# Natixis im Gespräch                                 0.000000  0.000000
# Mittelklasse, nur nicht beim Preis                  0.000000  0.000000
# Bleibt doch noch ein bisschen                       0.000000  0.000000
# Der Brandbeschleuniger im Weißen Haus               0.000000  0.000000
# Schweizer Banken Die Zeiten, um an den Finanzmä...  0.000000  0.000000
# Bankenmarkt                                         0.000000  0.000000
# Deutschland sucht das Super-SUV                     0.000000  0.000000
# Die Mailänder Börse ist in Feierlaune               0.000000  0.000000
# Trump, Trump und nochmals Trump                     0.000000  0.000000
# Basel IV                                            0.000000  0.000000
# Jetzt wird Bayern nervös                            3.218876  0.000000
# BMW setzt noch einen drauf                          0.000000  3.218876
# Klopp geht all in und gewinnt                       0.000000  0.000000
#
#                                                       109900    ...      \
# Zweite Bundesliga                                   0.000000    ...
# Joachim Löw und die Nationalelf                     0.000000    ...
# Konkurrenz für Netflix                              0.000000    ...
# Blitz und Schatten                                  0.000000    ...
# Ladematte AirPower                                  0.000000    ...
# Weißes Haus rechnet mit Schließung der Grenze z...  0.000000    ...
# Was Kim kann, kann Trump auch                       0.000000    ...
# Dramatischer Liverpool-Sieg durch spätes Eigentor   0.000000    ...
# Hollywood-Stars präsentieren                        0.000000    ...
# Tesla im Fahrtest                                   0.000000    ...
# Lebensrettende Massnahmen für Apple TV              0.000000    ...
# Der Vorwurf eines unerwünschten Kusses              0.000000    ...
# Natixis im Gespräch                                 0.000000    ...
# Mittelklasse, nur nicht beim Preis                  0.000000    ...
# Bleibt doch noch ein bisschen                       0.000000    ...
# Der Brandbeschleuniger im Weißen Haus               0.000000    ...
# Schweizer Banken Die Zeiten, um an den Finanzmä...  0.000000    ...
# Bankenmarkt                                         0.000000    ...
# Deutschland sucht das Super-SUV                     0.000000    ...
# Die Mailänder Börse ist in Feierlaune               0.000000    ...
# Trump, Trump und nochmals Trump                     0.000000    ...
# Basel IV                                            0.000000    ...
# Jetzt wird Bayern nervös                            0.000000    ...
# BMW setzt noch einen drauf                          3.218876    ...
# Klopp geht all in und gewinnt                       0.000000    ...
#
#                                                     übertragenden  \
# Zweite Bundesliga                                        0.000000
# Joachim Löw und die Nationalelf                          0.000000
# Konkurrenz für Netflix                                   0.000000
# Blitz und Schatten                                       0.000000
# Ladematte AirPower                                       0.000000
# Weißes Haus rechnet mit Schließung der Grenze z...       0.000000
# Was Kim kann, kann Trump auch                            0.000000
# Dramatischer Liverpool-Sieg durch spätes Eigentor        0.000000
# Hollywood-Stars präsentieren                             0.000000
# Tesla im Fahrtest                                        0.000000
# Lebensrettende Massnahmen für Apple TV                   0.000000
# Der Vorwurf eines unerwünschten Kusses                   0.000000
# Natixis im Gespräch                                      0.000000
# Mittelklasse, nur nicht beim Preis                       0.000000
# Bleibt doch noch ein bisschen                            0.000000
# Der Brandbeschleuniger im Weißen Haus                    0.000000
# Schweizer Banken Die Zeiten, um an den Finanzmä...       0.000000
# Bankenmarkt                                              0.000000
# Deutschland sucht das Super-SUV                          0.000000
# Die Mailänder Börse ist in Feierlaune                    0.000000
# Trump, Trump und nochmals Trump                          0.000000
# Basel IV                                                 0.000000
# Jetzt wird Bayern nervös                                 0.000000
# BMW setzt noch einen drauf                               0.000000
# Klopp geht all in und gewinnt                            3.218876
#
#                                                     übertrieben  überzeugen  \
# Zweite Bundesliga                                      0.000000    0.000000
# Joachim Löw und die Nationalelf                        0.000000    0.000000
# Konkurrenz für Netflix                                 0.000000    0.000000
# Blitz und Schatten                                     0.000000    0.000000
# Ladematte AirPower                                     0.000000    0.000000
# Weißes Haus rechnet mit Schließung der Grenze z...     0.000000    0.000000
# Was Kim kann, kann Trump auch                          0.000000    0.000000
# Dramatischer Liverpool-Sieg durch spätes Eigentor      0.000000    0.000000
# Hollywood-Stars präsentieren                           0.000000    0.000000
# Tesla im Fahrtest                                      0.000000    2.120264
# Lebensrettende Massnahmen für Apple TV                 0.000000    0.000000
# Der Vorwurf eines unerwünschten Kusses                 0.000000    0.000000
# Natixis im Gespräch                                    0.000000    0.000000
# Mittelklasse, nur nicht beim Preis                     0.000000    0.000000
# Bleibt doch noch ein bisschen                          0.000000    2.120264
# Der Brandbeschleuniger im Weißen Haus                  0.000000    0.000000
# Schweizer Banken Die Zeiten, um an den Finanzmä...     3.218876    0.000000
# Bankenmarkt                                            0.000000    0.000000
# Deutschland sucht das Super-SUV                        0.000000    0.000000
# Die Mailänder Börse ist in Feierlaune                  0.000000    0.000000
# Trump, Trump und nochmals Trump                        0.000000    0.000000
# Basel IV                                               0.000000    0.000000
# Jetzt wird Bayern nervös                               0.000000    0.000000
# BMW setzt noch einen drauf                             0.000000    0.000000
# Klopp geht all in und gewinnt                          0.000000    2.120264
#
#                                                     überzeugt      üble  \
# Zweite Bundesliga                                    0.000000  0.000000
# Joachim Löw und die Nationalelf                      0.000000  0.000000
# Konkurrenz für Netflix                               0.000000  0.000000
# Blitz und Schatten                                   0.000000  0.000000
# Ladematte AirPower                                   2.525729  0.000000
# Weißes Haus rechnet mit Schließung der Grenze z...   0.000000  0.000000
# Was Kim kann, kann Trump auch                        0.000000  0.000000
# Dramatischer Liverpool-Sieg durch spätes Eigentor    0.000000  0.000000
# Hollywood-Stars präsentieren                         0.000000  0.000000
# Tesla im Fahrtest                                    0.000000  0.000000
# Lebensrettende Massnahmen für Apple TV               0.000000  0.000000
# Der Vorwurf eines unerwünschten Kusses               0.000000  0.000000
# Natixis im Gespräch                                  0.000000  0.000000
# Mittelklasse, nur nicht beim Preis                   0.000000  0.000000
# Bleibt doch noch ein bisschen                        0.000000  0.000000
# Der Brandbeschleuniger im Weißen Haus                0.000000  0.000000
# Schweizer Banken Die Zeiten, um an den Finanzmä...   2.525729  0.000000
# Bankenmarkt                                          0.000000  0.000000
# Deutschland sucht das Super-SUV                      0.000000  0.000000
# Die Mailänder Börse ist in Feierlaune                0.000000  0.000000
# Trump, Trump und nochmals Trump                      0.000000  0.000000
# Basel IV                                             0.000000  0.000000
# Jetzt wird Bayern nervös                             0.000000  3.218876
# BMW setzt noch einen drauf                           0.000000  0.000000
# Klopp geht all in und gewinnt                        0.000000  0.000000
#
#                                                     üblicherweise     übrig  \
# Zweite Bundesliga                                        0.000000  0.000000
# Joachim Löw und die Nationalelf                          0.000000  0.000000
# Konkurrenz für Netflix                                   2.525729  0.000000
# Blitz und Schatten                                       0.000000  0.000000
# Ladematte AirPower                                       0.000000  0.000000
# Weißes Haus rechnet mit Schließung der Grenze z...       0.000000  0.000000
# Was Kim kann, kann Trump auch                            0.000000  0.000000
# Dramatischer Liverpool-Sieg durch spätes Eigentor        0.000000  0.000000
# Hollywood-Stars präsentieren                             2.525729  0.000000
# Tesla im Fahrtest                                        0.000000  0.000000
# Lebensrettende Massnahmen für Apple TV                   0.000000  0.000000
# Der Vorwurf eines unerwünschten Kusses                   0.000000  0.000000
# Natixis im Gespräch                                      0.000000  0.000000
# Mittelklasse, nur nicht beim Preis                       0.000000  0.000000
# Bleibt doch noch ein bisschen                            0.000000  0.000000
# Der Brandbeschleuniger im Weißen Haus                    0.000000  0.000000
# Schweizer Banken Die Zeiten, um an den Finanzmä...       0.000000  0.000000
# Bankenmarkt                                              0.000000  3.218876
# Deutschland sucht das Super-SUV                          0.000000  0.000000
# Die Mailänder Börse ist in Feierlaune                    0.000000  0.000000
# Trump, Trump und nochmals Trump                          0.000000  0.000000
# Basel IV                                                 0.000000  0.000000
# Jetzt wird Bayern nervös                                 0.000000  0.000000
# BMW setzt noch einen drauf                               0.000000  0.000000
# Klopp geht all in und gewinnt                            0.000000  0.000000
#
#                                                        üppig   üppiger  \
# Zweite Bundesliga                                   0.000000  0.000000
# Joachim Löw und die Nationalelf                     0.000000  0.000000
# Konkurrenz für Netflix                              0.000000  0.000000
# Blitz und Schatten                                  3.218876  0.000000
# Ladematte AirPower                                  0.000000  0.000000
# Weißes Haus rechnet mit Schließung der Grenze z...  0.000000  0.000000
# Was Kim kann, kann Trump auch                       0.000000  0.000000
# Dramatischer Liverpool-Sieg durch spätes Eigentor   0.000000  0.000000
# Hollywood-Stars präsentieren                        0.000000  0.000000
# Tesla im Fahrtest                                   0.000000  0.000000
# Lebensrettende Massnahmen für Apple TV              0.000000  0.000000
# Der Vorwurf eines unerwünschten Kusses              0.000000  0.000000
# Natixis im Gespräch                                 0.000000  0.000000
# Mittelklasse, nur nicht beim Preis                  0.000000  0.000000
# Bleibt doch noch ein bisschen                       0.000000  0.000000
# Der Brandbeschleuniger im Weißen Haus               0.000000  0.000000
# Schweizer Banken Die Zeiten, um an den Finanzmä...  0.000000  0.000000
# Bankenmarkt                                         0.000000  0.000000
# Deutschland sucht das Super-SUV                     0.000000  3.218876
# Die Mailänder Börse ist in Feierlaune               0.000000  0.000000
# Trump, Trump und nochmals Trump                     0.000000  0.000000
# Basel IV                                            0.000000  0.000000
# Jetzt wird Bayern nervös                            0.000000  0.000000
# BMW setzt noch einen drauf                          0.000000  0.000000
# Klopp geht all in und gewinnt                       0.000000  0.000000
#
#                                                             €
# Zweite Bundesliga                                    0.000000
# Joachim Löw und die Nationalelf                      0.000000
# Konkurrenz für Netflix                               0.000000
# Blitz und Schatten                                   0.000000
# Ladematte AirPower                                   0.000000
# Weißes Haus rechnet mit Schließung der Grenze z...   0.000000
# Was Kim kann, kann Trump auch                        0.000000
# Dramatischer Liverpool-Sieg durch spätes Eigentor    0.000000
# Hollywood-Stars präsentieren                         0.000000
# Tesla im Fahrtest                                    0.000000
# Lebensrettende Massnahmen für Apple TV               0.000000
# Der Vorwurf eines unerwünschten Kusses               0.000000
# Natixis im Gespräch                                  0.000000
# Mittelklasse, nur nicht beim Preis                   0.000000
# Bleibt doch noch ein bisschen                        0.000000
# Der Brandbeschleuniger im Weißen Haus                0.000000
# Schweizer Banken Die Zeiten, um an den Finanzmä...   0.000000
# Bankenmarkt                                          0.000000
# Deutschland sucht das Super-SUV                      0.000000
# Die Mailänder Börse ist in Feierlaune               12.875503
# Trump, Trump und nochmals Trump                      0.000000
# Basel IV                                             0.000000
# Jetzt wird Bayern nervös                             0.000000
# BMW setzt noch einen drauf                           0.000000
# Klopp geht all in und gewinnt                        0.000000
#
# [25 rows x 4599 columns]

# %%
vektor = tfidfDF.loc[['BMW setzt noch einen drauf']]
vektorTransponiert = vektor.transpose()
vektorSorted = vektorTransponiert.sort_values(by=['BMW setzt noch einen drauf'], ascending=False)
vektorSorted[:10]
# Out:
#           BMW setzt noch einen drauf
# x5                         25.257286
# x7                         15.154372
# bmw                        12.721581
# liter                      10.995489
# ps                          9.162907
# kostet                      7.577186
# variante                    6.437752
# einstieg                    6.437752
# mittlere                    6.437752
# motoren                     6.437752

# %% [markdown]
# ![Keyword-Suche](<./Grafiken/Agenda/Keyword.jpg>)

# %% [markdown]
# # Anwendungsbeispiel: Keywordsuche

# %%
vocabulary = get_vocabulary(stopwordsRemoved)
bow, bowDF = bag_of_words(stopwordsRemoved, vocabulary)
tf, tfDF = term_frequency(bow, stopwordsRemoved)
idf = inverse_document_frequency(bow)
tfidf, tfidfDF = term_frequency_inverse_document_frequency(bow, idf)

# %% [markdown]
# # Erstellen einer Keywordsuche

# %% [markdown]
# ![Keywordsuche](./Grafiken/KeywordSearch.jpg)

# %%
def search_keyword(keyword, tfidfDataFrame):

    searchList = []
    for doc in tfidfDataFrame:
        vec = tfidfDataFrame[doc]
        if vec.get(keyword) != 0:
            tfidf_value = vec.get(keyword)
            searchList.append([tfidf_value, doc])
    return sorted(searchList, reverse=True)

# %%
def search_top_word_documents(keyword, tfidfDataFrame):
    
    topDocsList = []
    docList = []
    topWordDocuments = {}
    for doc in tfidfDataFrame:
        vec = tfidfDataFrame[doc]
        if vec.get(keyword) != 0:
            topDocsList.append(doc)
        topWordDocuments[keyword] = topDocsList
    return(topWordDocuments)

# %%
def get_top_words(document, n, tfidfDataFrame):
    
    topDict = {}
    topList = []
    vec = tfidfDataFrame[document]
    sorted_vec = vec.sort_values(ascending=False)
    top = sorted_vec[0:n]
    for i, row in top.iteritems():
        if i != keyword:
            topList.append(i)
    topDict[document] = topList[0:n-2]
    return(topDict)

# %%
def get_top_words_documents(docName, relDocs, tfidfDataFrame):
    
    wordList = []
    topWordDocList = []
    wordList = relDocs.get(docName)
    for word in wordList:
        topWordDocList.append(search_top_word_documents(word, tfidfDataFrame))
    return(topWordDocList)

# %%
def related_docs(docs, n, tfidfDataFrame):
    
    relatedDocs = []
    n += 2
    for doc in docs:
        docName = doc[1]
        relDocs = get_top_words(docName, n, tfidfDataFrame)
        topWordDocs = get_top_words_documents(docName, relDocs, tfidfDataFrame)
        relatedDocs.append([doc[1], relDocs, topWordDocs])
    return(relatedDocs)

# %%
def keyword_search(keyword, tfidfDataFrame):
    search = search_keyword(keyword, tfidfDataFrame)
    complete = related_docs(search, 5, tfidfDataFrame)
    return(complete)

tfidfDataFrame = tfidfDF.transpose()

keyword = 'apple'
result = keyword_search(keyword, tfidfDataFrame)

i = 1

print('SUCHBEGRIFF: ' + keyword)
print('Gefunden in folgenden Dokumenten:')
print('_'*100)
print('')
for res in result:
    print('RANG: ' + str(i))
    print('DOKUMENT: ' + res[0])
    print('Weitere, wichtige Begriffe in "' + res[0] + '":')
    topWords = res[1].get(res[0])
    topDocuments = res[2]
    for topW in topWords:
        for topD in topDocuments:
            if topD.get(topW) != None:
                x = topD.get(topW)
                print('"' + str(topW) + '"' + ', bedeutsam in: "' + x[0] + '"')
    i+=1
    print('_'*100)
    print('')
# Out:
# SUCHBEGRIFF: apple
# Gefunden in folgenden Dokumenten:
# ____________________________________________________________________________________________________
#
# RANG: 1
# DOKUMENT: Hollywood-Stars präsentieren
# Weitere, wichtige Begriffe in "Hollywood-Stars präsentieren":
# "kreditkarte", bedeutsam in: "Konkurrenz für Netflix"
# "nachrichtenportal", bedeutsam in: "Hollywood-Stars präsentieren"
# "tv", bedeutsam in: "Hollywood-Stars präsentieren"
# "verfügbar", bedeutsam in: "Hollywood-Stars präsentieren"
# "dienst", bedeutsam in: "Konkurrenz für Netflix"
# ____________________________________________________________________________________________________
#
# RANG: 2
# DOKUMENT: Konkurrenz für Netflix
# Weitere, wichtige Begriffe in "Konkurrenz für Netflix":
# "konzern", bedeutsam in: "Konkurrenz für Netflix"
# "shows", bedeutsam in: "Konkurrenz für Netflix"
# "netflix", bedeutsam in: "Konkurrenz für Netflix"
# "inhalte", bedeutsam in: "Konkurrenz für Netflix"
# "zufolge", bedeutsam in: "Konkurrenz für Netflix"
# ____________________________________________________________________________________________________
#
# RANG: 3
# DOKUMENT: Bleibt doch noch ein bisschen
# Weitere, wichtige Begriffe in "Bleibt doch noch ein bisschen":
# "google", bedeutsam in: "Bleibt doch noch ein bisschen"
# "thing", bedeutsam in: "Bleibt doch noch ein bisschen"
# "more", bedeutsam in: "Bleibt doch noch ein bisschen"
# "one", bedeutsam in: "Bleibt doch noch ein bisschen"
# "konzern", bedeutsam in: "Konkurrenz für Netflix"
# ____________________________________________________________________________________________________
#
# RANG: 4
# DOKUMENT: Ladematte AirPower
# Weitere, wichtige Begriffe in "Ladematte AirPower":
# "airpower", bedeutsam in: "Ladematte AirPower"
# "matte", bedeutsam in: "Ladematte AirPower"
# "ladematte", bedeutsam in: "Ladematte AirPower"
# "geräten", bedeutsam in: "Ladematte AirPower"
# "problemen", bedeutsam in: "Ladematte AirPower"
# ____________________________________________________________________________________________________
#
# RANG: 5
# DOKUMENT: Lebensrettende Massnahmen für Apple TV
# Weitere, wichtige Begriffe in "Lebensrettende Massnahmen für Apple TV":
# "tv", bedeutsam in: "Hollywood-Stars präsentieren"
# "laut", bedeutsam in: "Lebensrettende Massnahmen für Apple TV"
# "appletvbox", bedeutsam in: "Lebensrettende Massnahmen für Apple TV"
# "hdmistick", bedeutsam in: "Lebensrettende Massnahmen für Apple TV"
# "version", bedeutsam in: "Tesla im Fahrtest"
# ____________________________________________________________________________________________________

# %% [markdown]
# ![Agenda](<./Grafiken/Agenda/Clustering.jpg>)

# %% [markdown]
# # Exkurs: Clustering
#
# ### -Clustering dient der Unterteilung von Daten in Gruppen ähnlicher Art
# ### -die Daten innerhalb eines Clusters sollen möglichst ähnlich zueinander sein
# ### -Cluster sollen zueinander möglichst unähnlich sein

# %% [markdown]
# ## Ungeordnete Daten:
# ![Data_Unsorted](./Grafiken/Data_Unsorted.jpg)

# %% [markdown]
# ## In Gruppen, bzw. Cluster, unterteilte Daten:
# ![Data_Clustered](./Grafiken/Data_Clusterd.jpg)

# %% [markdown]
# # Der k-Means Algorithmus
# ### -einer der populärsten Clustering-Algorithmen
# ### -die Anzahl der Cluster (k) wird initial festgelegt

# %% [markdown]
# ## es werden k Zentroide als vorläufige Cluster-Mittelpunkte festeglegt:
# ![Clustering](./Grafiken/Start_Centroids.jpg)

# %% [markdown]
# ## anschließend erfolgt für jeden Datenpunkt die Berechnung der Distanzen zu den vorhandenen Zentroiden:
# ![Clustering](./Grafiken/Centroid_Distances.jpg)

# %% [markdown]
# ## ein Datenpunkt wird jenem Zentroid zugeordnet, zu welchem er die geringste Distanz besitzt:
# ![Clustering](./Grafiken/Centroid_Assignment.jpg)

# %% [markdown]
# ## wurden alle Datenpunkte einem Zentroid zugeordnet, so werden diese auf Basis des Mittelwertes der Datenpunkte des eigenen Clusters neu verteilt:
# ![Clustering](./Grafiken/Moved_Centroids.jpg)

# %% [markdown]
# ## das Verfahren wird so oft wiederholt, bis keine Verschiebung der Zentroide mehr stattfindet
# ![Clustering](./Grafiken/Final_Centroids.jpg)

# %% [markdown]
# ![Document-Clustering](<./Grafiken/Agenda/Document-Clustering.jpg>)

# %% [markdown]
# # Anwendungsbeispiel: Clustering
#
# ![Clustering](./Grafiken/Clustering.jpg)

# %%
import pandas as pd

dataframe = pd.DataFrame.from_dict(documents, orient = 'index')
dataframe.reset_index(level=0, inplace=True)
dataframe.columns = ['file', 'token']

# %%
import pandas as pd

dataframe = pd.DataFrame.from_dict(documents, orient = 'index')
dataframe.reset_index(level=0, inplace=True)
dataframe.columns = ['file', 'token']
dataframe = dataframe.sort_values(by=['file'])
dataframe = dataframe.reset_index(drop=True)
dataframe
# Out:
#                                                  file  \
# 0                          BMW setzt noch einen drauf
# 1                                         Bankenmarkt
# 2                                            Basel IV
# 3                       Bleibt doch noch ein bisschen
# 4                                  Blitz und Schatten
# 5               Der Brandbeschleuniger im Weißen Haus
# 6              Der Vorwurf eines unerwünschten Kusses
# 7                     Deutschland sucht das Super-SUV
# 8               Die Mailänder Börse ist in Feierlaune
# 9   Dramatischer Liverpool-Sieg durch spätes Eigentor
# 10                       Hollywood-Stars präsentieren
# 11                           Jetzt wird Bayern nervös
# 12                    Joachim Löw und die Nationalelf
# 13                      Klopp geht all in und gewinnt
# 14                             Konkurrenz für Netflix
# 15                                 Ladematte AirPower
# 16             Lebensrettende Massnahmen für Apple TV
# 17                 Mittelklasse, nur nicht beim Preis
# 18                                Natixis im Gespräch
# 19  Schweizer Banken Die Zeiten, um an den Finanzm...
# 20                                  Tesla im Fahrtest
# 21                    Trump, Trump und nochmals Trump
# 22                      Was Kim kann, kann Trump auch
# 23  Weißes Haus rechnet mit Schließung der Grenze ...
# 24                                  Zweite Bundesliga
#
#                                                 token
# 0   ['Für alle, denen der mächtige X5 nicht groß g...
# 1   ['Sparkassen und Volksbanken graben Privatbank...
# 2   ['Bankenregulierung könnte Kredite verteuern\n...
# 3   ['Schön sind Apple-Produkte weiterhin. Aber da...
# 4   ['Der Opel Insignia Grand Sport ist viel gutes...
# 5   ['Donald Trump ist nur ein Symbol für eine vie...
# 6   ['Noch ist nicht klar, ob Joe Biden für das Am...
# 7   ['Fast jedes dritte neue Auto in Deutschland i...
# 8   ['Nach dem Horrorjahr 2018 ist die Piazza Affa...
# 9   ['Der Titelkampf in England zwischen Klopp und...
# 10  ['Videostream, Kreditkarte und News - alles vo...
# 11  ['Huch! Weil Bayern in Freiburg frühjahrsmüde ...
# 12  ['Der Bundestrainer beobachtet beim Spiel in F...
# 13  ['Glücklich bleibt der FC Liverpool Tabellenfü...
# 14  ['Showtime für Apple\n', 'Der Elektronikkonzer...
# 15  ['Apple scheitert erstmals bei Entwicklung ein...
# 16  ['Apple liebäugelt mit einer günstigen Version...
# 17  ['Der Audi Q3 bietet mehr Fahrdynamik, der Vol...
# 18  ['Investmentbanking braucht einen Fokus\n', 'E...
# 19  ['In den ersten drei Monaten des Jahres haben ...
# 20  ['Teslas Mittelklasse-Stromer ist aktuell konk...
# 21  ['Wie sollen die Medien auf die Schelten des U...
# 22  ['Der nordkoreanische Machthaber Kim Jong Un h...
# 23  ['Im Umfeld des Weißen Hauses mehren sich die ...
# 24  ['Nullnummer im Nachholspiel\n', 'Viel Kampf, ...

# %%
vocabulary = get_vocabulary(stopwordsRemoved)
bow, bowDF = bag_of_words(stopwordsRemoved, vocabulary)
tf, tfDF = term_frequency(bow, stopwordsRemoved)
idf = inverse_document_frequency(bow)
tfidf, tfidfDF = term_frequency_inverse_document_frequency(bow, idf)

# %%
tfidfDF = tfidfDF.sort_index()
tfidfDF
# Out:
#                                                                00       000  \
# BMW setzt noch einen drauf                          0.0  0.000000  0.000000
# Bankenmarkt                                         0.0  0.000000  0.000000
# Basel IV                                            0.0  0.000000  0.000000
# Bleibt doch noch ein bisschen                       0.0  0.000000  0.000000
# Blitz und Schatten                                  0.0  0.000000  0.000000
# Der Brandbeschleuniger im Weißen Haus               0.0  0.000000  0.000000
# Der Vorwurf eines unerwünschten Kusses              0.0  0.000000  0.000000
# Deutschland sucht das Super-SUV                     0.0  0.000000  0.000000
# Die Mailänder Börse ist in Feierlaune               0.0  0.000000  0.000000
# Dramatischer Liverpool-Sieg durch spätes Eigentor   0.0  0.000000  0.000000
# Hollywood-Stars präsentieren                        0.0  0.000000  0.000000
# Jetzt wird Bayern nervös                            0.0  0.000000  0.000000
# Joachim Löw und die Nationalelf                     0.0  0.000000  0.000000
# Klopp geht all in und gewinnt                       0.0  0.000000  1.832581
# Konkurrenz für Netflix                              0.0  0.000000  0.000000
# Ladematte AirPower                                  0.0  0.000000  0.000000
# Lebensrettende Massnahmen für Apple TV              0.0  0.000000  0.000000
# Mittelklasse, nur nicht beim Preis                  0.0  0.000000  3.665163
# Natixis im Gespräch                                 0.0  0.000000  0.000000
# Schweizer Banken Die Zeiten, um an den Finanzmä...  0.0  0.000000  0.000000
# Tesla im Fahrtest                                   0.0  0.000000  3.665163
# Trump, Trump und nochmals Trump                     0.0  0.000000  0.000000
# Was Kim kann, kann Trump auch                       0.0  0.000000  0.000000
# Weißes Haus rechnet mit Schließung der Grenze z...  0.0  0.000000  1.832581
# Zweite Bundesliga                                   0.0  3.218876  0.000000
#
#                                                           02        03  \
# BMW setzt noch einen drauf                          0.000000  0.000000
# Bankenmarkt                                         0.000000  0.000000
# Basel IV                                            0.000000  0.000000
# Bleibt doch noch ein bisschen                       0.000000  0.000000
# Blitz und Schatten                                  0.000000  0.000000
# Der Brandbeschleuniger im Weißen Haus               0.000000  0.000000
# Der Vorwurf eines unerwünschten Kusses              0.000000  0.000000
# Deutschland sucht das Super-SUV                     0.000000  0.000000
# Die Mailänder Börse ist in Feierlaune               0.000000  0.000000
# Dramatischer Liverpool-Sieg durch spätes Eigentor   5.051457  0.000000
# Hollywood-Stars präsentieren                        0.000000  0.000000
# Jetzt wird Bayern nervös                            0.000000  0.000000
# Joachim Löw und die Nationalelf                     2.525729  3.218876
# Klopp geht all in und gewinnt                       0.000000  0.000000
# Konkurrenz für Netflix                              0.000000  0.000000
# Ladematte AirPower                                  0.000000  0.000000
# Lebensrettende Massnahmen für Apple TV              0.000000  0.000000
# Mittelklasse, nur nicht beim Preis                  0.000000  0.000000
# Natixis im Gespräch                                 0.000000  0.000000
# Schweizer Banken Die Zeiten, um an den Finanzmä...  0.000000  0.000000
# Tesla im Fahrtest                                   0.000000  0.000000
# Trump, Trump und nochmals Trump                     0.000000  0.000000
# Was Kim kann, kann Trump auch                       0.000000  0.000000
# Weißes Haus rechnet mit Schließung der Grenze z...  0.000000  0.000000
# Zweite Bundesliga                                   0.000000  0.000000
#
#                                                           10       100  \
# BMW setzt noch einen drauf                          0.000000  0.000000
# Bankenmarkt                                         0.000000  0.000000
# Basel IV                                            0.000000  0.000000
# Bleibt doch noch ein bisschen                       0.000000  0.000000
# Blitz und Schatten                                  0.000000  0.000000
# Der Brandbeschleuniger im Weißen Haus               0.000000  0.000000
# Der Vorwurf eines unerwünschten Kusses              0.000000  0.000000
# Deutschland sucht das Super-SUV                     1.609438  4.240527
# Die Mailänder Börse ist in Feierlaune               0.000000  0.000000
# Dramatischer Liverpool-Sieg durch spätes Eigentor   3.218876  0.000000
# Hollywood-Stars präsentieren                        0.000000  2.120264
# Jetzt wird Bayern nervös                            1.609438  0.000000
# Joachim Löw und die Nationalelf                     1.609438  0.000000
# Klopp geht all in und gewinnt                       0.000000  0.000000
# Konkurrenz für Netflix                              0.000000  0.000000
# Ladematte AirPower                                  0.000000  0.000000
# Lebensrettende Massnahmen für Apple TV              0.000000  0.000000
# Mittelklasse, nur nicht beim Preis                  0.000000  0.000000
# Natixis im Gespräch                                 0.000000  0.000000
# Schweizer Banken Die Zeiten, um an den Finanzmä...  1.609438  0.000000
# Tesla im Fahrtest                                   0.000000  0.000000
# Trump, Trump und nochmals Trump                     0.000000  0.000000
# Was Kim kann, kann Trump auch                       0.000000  0.000000
# Weißes Haus rechnet mit Schließung der Grenze z...  0.000000  2.120264
# Zweite Bundesliga                                   0.000000  0.000000
#
#                                                        10000       105  \
# BMW setzt noch einen drauf                          0.000000  3.218876
# Bankenmarkt                                         0.000000  0.000000
# Basel IV                                            0.000000  0.000000
# Bleibt doch noch ein bisschen                       0.000000  0.000000
# Blitz und Schatten                                  0.000000  0.000000
# Der Brandbeschleuniger im Weißen Haus               0.000000  0.000000
# Der Vorwurf eines unerwünschten Kusses              0.000000  0.000000
# Deutschland sucht das Super-SUV                     0.000000  0.000000
# Die Mailänder Börse ist in Feierlaune               0.000000  0.000000
# Dramatischer Liverpool-Sieg durch spätes Eigentor   0.000000  0.000000
# Hollywood-Stars präsentieren                        0.000000  0.000000
# Jetzt wird Bayern nervös                            3.218876  0.000000
# Joachim Löw und die Nationalelf                     0.000000  0.000000
# Klopp geht all in und gewinnt                       0.000000  0.000000
# Konkurrenz für Netflix                              0.000000  0.000000
# Ladematte AirPower                                  0.000000  0.000000
# Lebensrettende Massnahmen für Apple TV              0.000000  0.000000
# Mittelklasse, nur nicht beim Preis                  0.000000  0.000000
# Natixis im Gespräch                                 0.000000  0.000000
# Schweizer Banken Die Zeiten, um an den Finanzmä...  0.000000  0.000000
# Tesla im Fahrtest                                   0.000000  0.000000
# Trump, Trump und nochmals Trump                     0.000000  0.000000
# Was Kim kann, kann Trump auch                       0.000000  0.000000
# Weißes Haus rechnet mit Schließung der Grenze z...  0.000000  0.000000
# Zweite Bundesliga                                   0.000000  0.000000
#
#                                                       109900    ...      \
# BMW setzt noch einen drauf                          3.218876    ...
# Bankenmarkt                                         0.000000    ...
# Basel IV                                            0.000000    ...
# Bleibt doch noch ein bisschen                       0.000000    ...
# Blitz und Schatten                                  0.000000    ...
# Der Brandbeschleuniger im Weißen Haus               0.000000    ...
# Der Vorwurf eines unerwünschten Kusses              0.000000    ...
# Deutschland sucht das Super-SUV                     0.000000    ...
# Die Mailänder Börse ist in Feierlaune               0.000000    ...
# Dramatischer Liverpool-Sieg durch spätes Eigentor   0.000000    ...
# Hollywood-Stars präsentieren                        0.000000    ...
# Jetzt wird Bayern nervös                            0.000000    ...
# Joachim Löw und die Nationalelf                     0.000000    ...
# Klopp geht all in und gewinnt                       0.000000    ...
# Konkurrenz für Netflix                              0.000000    ...
# Ladematte AirPower                                  0.000000    ...
# Lebensrettende Massnahmen für Apple TV              0.000000    ...
# Mittelklasse, nur nicht beim Preis                  0.000000    ...
# Natixis im Gespräch                                 0.000000    ...
# Schweizer Banken Die Zeiten, um an den Finanzmä...  0.000000    ...
# Tesla im Fahrtest                                   0.000000    ...
# Trump, Trump und nochmals Trump                     0.000000    ...
# Was Kim kann, kann Trump auch                       0.000000    ...
# Weißes Haus rechnet mit Schließung der Grenze z...  0.000000    ...
# Zweite Bundesliga                                   0.000000    ...
#
#                                                     übertragenden  \
# BMW setzt noch einen drauf                               0.000000
# Bankenmarkt                                              0.000000
# Basel IV                                                 0.000000
# Bleibt doch noch ein bisschen                            0.000000
# Blitz und Schatten                                       0.000000
# Der Brandbeschleuniger im Weißen Haus                    0.000000
# Der Vorwurf eines unerwünschten Kusses                   0.000000
# Deutschland sucht das Super-SUV                          0.000000
# Die Mailänder Börse ist in Feierlaune                    0.000000
# Dramatischer Liverpool-Sieg durch spätes Eigentor        0.000000
# Hollywood-Stars präsentieren                             0.000000
# Jetzt wird Bayern nervös                                 0.000000
# Joachim Löw und die Nationalelf                          0.000000
# Klopp geht all in und gewinnt                            3.218876
# Konkurrenz für Netflix                                   0.000000
# Ladematte AirPower                                       0.000000
# Lebensrettende Massnahmen für Apple TV                   0.000000
# Mittelklasse, nur nicht beim Preis                       0.000000
# Natixis im Gespräch                                      0.000000
# Schweizer Banken Die Zeiten, um an den Finanzmä...       0.000000
# Tesla im Fahrtest                                        0.000000
# Trump, Trump und nochmals Trump                          0.000000
# Was Kim kann, kann Trump auch                            0.000000
# Weißes Haus rechnet mit Schließung der Grenze z...       0.000000
# Zweite Bundesliga                                        0.000000
#
#                                                     übertrieben  überzeugen  \
# BMW setzt noch einen drauf                             0.000000    0.000000
# Bankenmarkt                                            0.000000    0.000000
# Basel IV                                               0.000000    0.000000
# Bleibt doch noch ein bisschen                          0.000000    2.120264
# Blitz und Schatten                                     0.000000    0.000000
# Der Brandbeschleuniger im Weißen Haus                  0.000000    0.000000
# Der Vorwurf eines unerwünschten Kusses                 0.000000    0.000000
# Deutschland sucht das Super-SUV                        0.000000    0.000000
# Die Mailänder Börse ist in Feierlaune                  0.000000    0.000000
# Dramatischer Liverpool-Sieg durch spätes Eigentor      0.000000    0.000000
# Hollywood-Stars präsentieren                           0.000000    0.000000
# Jetzt wird Bayern nervös                               0.000000    0.000000
# Joachim Löw und die Nationalelf                        0.000000    0.000000
# Klopp geht all in und gewinnt                          0.000000    2.120264
# Konkurrenz für Netflix                                 0.000000    0.000000
# Ladematte AirPower                                     0.000000    0.000000
# Lebensrettende Massnahmen für Apple TV                 0.000000    0.000000
# Mittelklasse, nur nicht beim Preis                     0.000000    0.000000
# Natixis im Gespräch                                    0.000000    0.000000
# Schweizer Banken Die Zeiten, um an den Finanzmä...     3.218876    0.000000
# Tesla im Fahrtest                                      0.000000    2.120264
# Trump, Trump und nochmals Trump                        0.000000    0.000000
# Was Kim kann, kann Trump auch                          0.000000    0.000000
# Weißes Haus rechnet mit Schließung der Grenze z...     0.000000    0.000000
# Zweite Bundesliga                                      0.000000    0.000000
#
#                                                     überzeugt      üble  \
# BMW setzt noch einen drauf                           0.000000  0.000000
# Bankenmarkt                                          0.000000  0.000000
# Basel IV                                             0.000000  0.000000
# Bleibt doch noch ein bisschen                        0.000000  0.000000
# Blitz und Schatten                                   0.000000  0.000000
# Der Brandbeschleuniger im Weißen Haus                0.000000  0.000000
# Der Vorwurf eines unerwünschten Kusses               0.000000  0.000000
# Deutschland sucht das Super-SUV                      0.000000  0.000000
# Die Mailänder Börse ist in Feierlaune                0.000000  0.000000
# Dramatischer Liverpool-Sieg durch spätes Eigentor    0.000000  0.000000
# Hollywood-Stars präsentieren                         0.000000  0.000000
# Jetzt wird Bayern nervös                             0.000000  3.218876
# Joachim Löw und die Nationalelf                      0.000000  0.000000
# Klopp geht all in und gewinnt                        0.000000  0.000000
# Konkurrenz für Netflix                               0.000000  0.000000
# Ladematte AirPower                                   2.525729  0.000000
# Lebensrettende Massnahmen für Apple TV               0.000000  0.000000
# Mittelklasse, nur nicht beim Preis                   0.000000  0.000000
# Natixis im Gespräch                                  0.000000  0.000000
# Schweizer Banken Die Zeiten, um an den Finanzmä...   2.525729  0.000000
# Tesla im Fahrtest                                    0.000000  0.000000
# Trump, Trump und nochmals Trump                      0.000000  0.000000
# Was Kim kann, kann Trump auch                        0.000000  0.000000
# Weißes Haus rechnet mit Schließung der Grenze z...   0.000000  0.000000
# Zweite Bundesliga                                    0.000000  0.000000
#
#                                                     üblicherweise     übrig  \
# BMW setzt noch einen drauf                               0.000000  0.000000
# Bankenmarkt                                              0.000000  3.218876
# Basel IV                                                 0.000000  0.000000
# Bleibt doch noch ein bisschen                            0.000000  0.000000
# Blitz und Schatten                                       0.000000  0.000000
# Der Brandbeschleuniger im Weißen Haus                    0.000000  0.000000
# Der Vorwurf eines unerwünschten Kusses                   0.000000  0.000000
# Deutschland sucht das Super-SUV                          0.000000  0.000000
# Die Mailänder Börse ist in Feierlaune                    0.000000  0.000000
# Dramatischer Liverpool-Sieg durch spätes Eigentor        0.000000  0.000000
# Hollywood-Stars präsentieren                             2.525729  0.000000
# Jetzt wird Bayern nervös                                 0.000000  0.000000
# Joachim Löw und die Nationalelf                          0.000000  0.000000
# Klopp geht all in und gewinnt                            0.000000  0.000000
# Konkurrenz für Netflix                                   2.525729  0.000000
# Ladematte AirPower                                       0.000000  0.000000
# Lebensrettende Massnahmen für Apple TV                   0.000000  0.000000
# Mittelklasse, nur nicht beim Preis                       0.000000  0.000000
# Natixis im Gespräch                                      0.000000  0.000000
# Schweizer Banken Die Zeiten, um an den Finanzmä...       0.000000  0.000000
# Tesla im Fahrtest                                        0.000000  0.000000
# Trump, Trump und nochmals Trump                          0.000000  0.000000
# Was Kim kann, kann Trump auch                            0.000000  0.000000
# Weißes Haus rechnet mit Schließung der Grenze z...       0.000000  0.000000
# Zweite Bundesliga                                        0.000000  0.000000
#
#                                                        üppig   üppiger  \
# BMW setzt noch einen drauf                          0.000000  0.000000
# Bankenmarkt                                         0.000000  0.000000
# Basel IV                                            0.000000  0.000000
# Bleibt doch noch ein bisschen                       0.000000  0.000000
# Blitz und Schatten                                  3.218876  0.000000
# Der Brandbeschleuniger im Weißen Haus               0.000000  0.000000
# Der Vorwurf eines unerwünschten Kusses              0.000000  0.000000
# Deutschland sucht das Super-SUV                     0.000000  3.218876
# Die Mailänder Börse ist in Feierlaune               0.000000  0.000000
# Dramatischer Liverpool-Sieg durch spätes Eigentor   0.000000  0.000000
# Hollywood-Stars präsentieren                        0.000000  0.000000
# Jetzt wird Bayern nervös                            0.000000  0.000000
# Joachim Löw und die Nationalelf                     0.000000  0.000000
# Klopp geht all in und gewinnt                       0.000000  0.000000
# Konkurrenz für Netflix                              0.000000  0.000000
# Ladematte AirPower                                  0.000000  0.000000
# Lebensrettende Massnahmen für Apple TV              0.000000  0.000000
# Mittelklasse, nur nicht beim Preis                  0.000000  0.000000
# Natixis im Gespräch                                 0.000000  0.000000
# Schweizer Banken Die Zeiten, um an den Finanzmä...  0.000000  0.000000
# Tesla im Fahrtest                                   0.000000  0.000000
# Trump, Trump und nochmals Trump                     0.000000  0.000000
# Was Kim kann, kann Trump auch                       0.000000  0.000000
# Weißes Haus rechnet mit Schließung der Grenze z...  0.000000  0.000000
# Zweite Bundesliga                                   0.000000  0.000000
#
#                                                             €
# BMW setzt noch einen drauf                           0.000000
# Bankenmarkt                                          0.000000
# Basel IV                                             0.000000
# Bleibt doch noch ein bisschen                        0.000000
# Blitz und Schatten                                   0.000000
# Der Brandbeschleuniger im Weißen Haus                0.000000
# Der Vorwurf eines unerwünschten Kusses               0.000000
# Deutschland sucht das Super-SUV                      0.000000
# Die Mailänder Börse ist in Feierlaune               12.875503
# Dramatischer Liverpool-Sieg durch spätes Eigentor    0.000000
# Hollywood-Stars präsentieren                         0.000000
# Jetzt wird Bayern nervös                             0.000000
# Joachim Löw und die Nationalelf                      0.000000
# Klopp geht all in und gewinnt                        0.000000
# Konkurrenz für Netflix                               0.000000
# Ladematte AirPower                                   0.000000
# Lebensrettende Massnahmen für Apple TV               0.000000
# Mittelklasse, nur nicht beim Preis                   0.000000
# Natixis im Gespräch                                  0.000000
# Schweizer Banken Die Zeiten, um an den Finanzmä...   0.000000
# Tesla im Fahrtest                                    0.000000
# Trump, Trump und nochmals Trump                      0.000000
# Was Kim kann, kann Trump auch                        0.000000
# Weißes Haus rechnet mit Schließung der Grenze z...   0.000000
# Zweite Bundesliga                                    0.000000
#
# [25 rows x 4599 columns]

# %%
from sklearn.cluster import KMeans
from collections import Counter
import pandas as pd
import numpy as np
import scipy
from scipy.sparse import csr_matrix

clustertfidfDF = scipy.sparse.csr_matrix(tfidfDF)

def kMeans_clustering(feature_matrix):
    
    km = KMeans(n_clusters=5, max_iter=10000)
    km.fit(feature_matrix.todense())
    clusters = km.labels_          
    return km, clusters

km_obj, clusters = kMeans_clustering(feature_matrix=clustertfidfDF)

cluster = pd.DataFrame(clusters)

dataframe['Cluster'] = cluster

c = Counter(clusters)
total_clusters=len(c)

cluster_details = {}  
    
ordered_centroids = km_obj.cluster_centers_.argsort()[:, ::-1]

topn_features=10

feature_names = sorted(vocabulary)

for cluster_num in range(total_clusters):
    cluster_details[cluster_num] = {}
    cluster_details[cluster_num]['cluster_num'] = cluster_num
    key_features = [feature_names[index]
                    for index
                    in ordered_centroids[cluster_num, :topn_features]]
    cluster_details[cluster_num]['key_features'] = key_features
    files = dataframe[dataframe['Cluster'] == cluster_num]['file'].values.tolist()
    cluster_details[cluster_num]['file'] = files
    
for cluster in cluster_details:
    print('Cluster: ' + str(cluster))
    print(' ')
    print('enthaltene Dokumente:')
    print(cluster_details.get(cluster).get('file'))
    print(' ')
    print('Keyfeatures: ')
    print(cluster_details.get(cluster).get('key_features'))
    print(' ')
    print('_'*150)
    print('_'*150)
    print(' ')
# Out:
# Cluster: 0
#
# enthaltene Dokumente:
# ['BMW setzt noch einen drauf', 'Deutschland sucht das Super-SUV', 'Mittelklasse, nur nicht beim Preis']
#
# Keyfeatures:
# ['bmw', 'x7', 'x5', 'glc', 'coupé', 'suv', 'ps', 'liter', 'xc40', 'volvo']
#
# ______________________________________________________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________________________________________________
#
# Cluster: 1
#
# enthaltene Dokumente:
# ['Hollywood-Stars präsentieren', 'Konkurrenz für Netflix']
#
# Keyfeatures:
# ['apple', 'kreditkarte', 'netflix', 'konzern', 'dienst', 'inhalte', 'montag', 'times', 'geräte', 'shows']
#
# ______________________________________________________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________________________________________________
#
# Cluster: 2
#
# enthaltene Dokumente:
# ['Bankenmarkt', 'Bleibt doch noch ein bisschen', 'Blitz und Schatten', 'Der Brandbeschleuniger im Weißen Haus', 'Der Vorwurf eines unerwünschten Kusses', 'Die Mailänder Börse ist in Feierlaune', 'Dramatischer Liverpool-Sieg durch spätes Eigentor', 'Jetzt wird Bayern nervös', 'Joachim Löw und die Nationalelf', 'Klopp geht all in und gewinnt', 'Ladematte AirPower', 'Lebensrettende Massnahmen für Apple TV', 'Natixis im Gespräch', 'Schweizer Banken Die Zeiten, um an den Finanzmärkten mutig zu sein, sind erst einmal vorbei', 'Trump, Trump und nochmals Trump', 'Was Kim kann, kann Trump auch', 'Weißes Haus rechnet mit Schließung der Grenze zu Mexiko', 'Zweite Bundesliga']
#
# Keyfeatures:
# ['apple', 'trump', 'sparkassen', 'liverpool', 'löw', 'airpower', 'klopp', 'investmentbanking', 'fc', 'präsidenten']
#
# ______________________________________________________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________________________________________________
#
# Cluster: 3
#
# enthaltene Dokumente:
# ['Tesla im Fahrtest']
#
# Keyfeatures:
# ['model', '3', 'tesla', 'reichweite', 'autopilot', 'aktuell', 'kilometer', 'wagen', 'autopiloten', 'smartphone']
#
# ______________________________________________________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________________________________________________
#
# Cluster: 4
#
# enthaltene Dokumente:
# ['Basel IV']
#
# Keyfeatures:
# ['banken', 'bankenverband', 'outputfloor', 'ksa', 'regulierung', 'kreditvergabe', 'deutsche', 'deutschland', 'angewendet', 'aktiva']
#
# ______________________________________________________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________________________________________________

# %%
import pandas as pd

dataframe = pd.DataFrame.from_dict(documents, orient = 'index')
dataframe.reset_index(level=0, inplace=True)
dataframe.columns = ['file', 'token']
dataframe = dataframe.sort_values(by=['file'])
dataframe = dataframe.reset_index(drop=True)
dataframe
# Out:
#                                                  file  \
# 0                          BMW setzt noch einen drauf
# 1                                         Bankenmarkt
# 2                                            Basel IV
# 3                       Bleibt doch noch ein bisschen
# 4                                  Blitz und Schatten
# 5               Der Brandbeschleuniger im Weißen Haus
# 6              Der Vorwurf eines unerwünschten Kusses
# 7                     Deutschland sucht das Super-SUV
# 8               Die Mailänder Börse ist in Feierlaune
# 9   Dramatischer Liverpool-Sieg durch spätes Eigentor
# 10                       Hollywood-Stars präsentieren
# 11                           Jetzt wird Bayern nervös
# 12                    Joachim Löw und die Nationalelf
# 13                      Klopp geht all in und gewinnt
# 14                             Konkurrenz für Netflix
# 15                                 Ladematte AirPower
# 16             Lebensrettende Massnahmen für Apple TV
# 17                 Mittelklasse, nur nicht beim Preis
# 18                                Natixis im Gespräch
# 19  Schweizer Banken Die Zeiten, um an den Finanzm...
# 20                                  Tesla im Fahrtest
# 21                    Trump, Trump und nochmals Trump
# 22                      Was Kim kann, kann Trump auch
# 23  Weißes Haus rechnet mit Schließung der Grenze ...
# 24                                  Zweite Bundesliga
#
#                                                 token
# 0   ['Für alle, denen der mächtige X5 nicht groß g...
# 1   ['Sparkassen und Volksbanken graben Privatbank...
# 2   ['Bankenregulierung könnte Kredite verteuern\n...
# 3   ['Schön sind Apple-Produkte weiterhin. Aber da...
# 4   ['Der Opel Insignia Grand Sport ist viel gutes...
# 5   ['Donald Trump ist nur ein Symbol für eine vie...
# 6   ['Noch ist nicht klar, ob Joe Biden für das Am...
# 7   ['Fast jedes dritte neue Auto in Deutschland i...
# 8   ['Nach dem Horrorjahr 2018 ist die Piazza Affa...
# 9   ['Der Titelkampf in England zwischen Klopp und...
# 10  ['Videostream, Kreditkarte und News - alles vo...
# 11  ['Huch! Weil Bayern in Freiburg frühjahrsmüde ...
# 12  ['Der Bundestrainer beobachtet beim Spiel in F...
# 13  ['Glücklich bleibt der FC Liverpool Tabellenfü...
# 14  ['Showtime für Apple\n', 'Der Elektronikkonzer...
# 15  ['Apple scheitert erstmals bei Entwicklung ein...
# 16  ['Apple liebäugelt mit einer günstigen Version...
# 17  ['Der Audi Q3 bietet mehr Fahrdynamik, der Vol...
# 18  ['Investmentbanking braucht einen Fokus\n', 'E...
# 19  ['In den ersten drei Monaten des Jahres haben ...
# 20  ['Teslas Mittelklasse-Stromer ist aktuell konk...
# 21  ['Wie sollen die Medien auf die Schelten des U...
# 22  ['Der nordkoreanische Machthaber Kim Jong Un h...
# 23  ['Im Umfeld des Weißen Hauses mehren sich die ...
# 24  ['Nullnummer im Nachholspiel\n', 'Viel Kampf, ...

# %%
def stopwords_string(tokenized):
    stopwords = ["ab","aber","ach","acht","achte","achten","achter","achtes","ag","alle","allein","allem","allen","aller","allerdings","alles","allgemeinen","als","also","am","an","ander","andere","anderem","anderen","anderer","anderes","anderm","andern","anderr","anders","au","auch","auf","aus","ausser","ausserdem","außer","außerdem","b","bald","bei","beide","beiden","beim","beispiel","bekannt","bereits","besonders","besser","besten","bin","bis","bisher","bist","c","d","d.h","da","dabei","dadurch","dafür","dagegen","daher","dahin","dahinter","damals","damit","danach","daneben","dank","dann","daran","darauf","daraus","darf","darfst","darin","darum","darunter","darüber","das","dasein","daselbst","dass","dasselbe","davon","davor","dazu","dazwischen","daß","dein","deine","deinem","deinen","deiner","deines","dem","dementsprechend","demgegenüber","demgemäss","demgemäß","demselben","demzufolge","den","denen","denn","denselben","der","deren","derer","derjenige","derjenigen","dermassen","dermaßen","derselbe","derselben","des","deshalb","desselben","dessen","deswegen","dich","die","diejenige","diejenigen","dies","diese","dieselbe","dieselben","diesem","diesen","dieser","dieses","dir","doch","dort","drei","drin","dritte","dritten","dritter","drittes","du","durch","durchaus","durfte","durften","dürfen","dürft","e","eben","ebenso","ehrlich","ei","ei,","eigen","eigene","eigenen","eigener","eigenes","ein","einander","eine","einem","einen","einer","eines","einig","einige","einigem","einigen","einiger","einiges","einmal","eins","elf","en","ende","endlich","entweder","er","ernst","erst","erste","ersten","erster","erstes","es","etwa","etwas","euch","euer","eure","eurem","euren","eurer","eures","f","folgende","früher","fünf","fünfte","fünften","fünfter","fünftes","für","g","gab","ganz","ganze","ganzen","ganzer","ganzes","gar","gedurft","gegen","gegenüber","gehabt","gehen","geht","gekannt","gekonnt","gemacht","gemocht","gemusst","genug","gerade","gern","gesagt","geschweige","gewesen","gewollt","geworden","gibt","ging","gleich","gott","gross","grosse","grossen","grosser","grosses","groß","große","großen","großer","großes","gut","gute","guter","gutes","h","hab","habe","haben","habt","hast","hat","hatte","hatten","hattest","hattet","heisst","her","heute","hier","hin","hinter","hoch","hätte","hätten","i","ich","ihm","ihn","ihnen","ihr","ihre","ihrem","ihren","ihrer","ihres","im","immer","in","indem","infolgedessen","ins","irgend","ist","j","ja","jahr","jahre","jahren","je","jede","jedem","jeden","jeder","jedermann","jedermanns","jedes","jedoch","jemand","jemandem","jemanden","jene","jenem","jenen","jener","jenes","jetzt","k","kam","kann","kannst","kaum","kein","keine","keinem","keinen","keiner","keines","kleine","kleinen","kleiner","kleines","kommen","kommt","konnte","konnten","kurz","können","könnt","könnte","l","lang","lange","leicht","leide","lieber","los","m","machen","macht","machte","mag","magst","mahn","mal","man","manche","manchem","manchen","mancher","manches","mann","mehr","mein","meine","meinem","meinen","meiner","meines","mensch","menschen","mich","mir","mit","mittel","mochte","mochten","morgen","muss","musst","musste","mussten","muß","mußt","möchte","mögen","möglich","mögt","müssen","müsst","müßt","n","na","nach","nachdem","nahm","natürlich","neben","nein","neue","neuen","neun","neunte","neunten","neunter","neuntes","nicht","nichts","nie","niemand","niemandem","niemanden","noch","nun","nur","o","ob","oben","oder","offen","oft","ohne","ordnung","p","q","r","recht","rechte","rechten","rechter","rechtes","richtig","rund","s","sa","sache","sagt","sagte","sah","satt","schlecht","schluss","schon","sechs","sechste","sechsten","sechster","sechstes","sehr","sei","seid","seien","sein","seine","seinem","seinen","seiner","seines","seit","seitdem","selbst","sich","sie","sieben","siebente","siebenten","siebenter","siebentes","sind","so","solang","solche","solchem","solchen","solcher","solches","soll","sollen","sollst","sollt","sollte","sollten","sondern","sonst","soweit","sowie","später","startseite","statt","steht","suche","t","tag","tage","tagen","tat","teil","tel","tritt","trotzdem","tun","u","uhr","um","und","und?","uns","unse","unsem","unsen","unser","unsere","unserer","unses","unter","v","vergangenen","viel","viele","vielem","vielen","vielleicht","vier","vierte","vierten","vierter","viertes","vom","von","vor","w","wahr?","wann","war","waren","warst","wart","warum","was","weg","wegen","weil","weit","weiter","weitere","weiteren","weiteres","welche","welchem","welchen","welcher","welches","wem","wen","wenig","wenige","weniger","weniges","wenigstens","wenn","wer","werde","werden","werdet","weshalb","wessen","wie","wieder","wieso","will","willst","wir","wird","wirklich","wirst","wissen","wo","woher","wohin","wohl","wollen","wollt","wollte","wollten","worden","wurde","wurden","während","währenddem","währenddessen","wäre","würde","würden","x","y","z","z.b","zehn","zehnte","zehnten","zehnter","zehntes","zeit","zu","zuerst","zugleich","zum","zunächst","zur","zurück","zusammen","zwanzig","zwar","zwei","zweite","zweiten","zweiter","zweites","zwischen","zwölf","über","überhaupt","übrigens"]
    
    removed = {}
    
    for doc in tokenized:
        document = tokenized.get(doc)
        no_stopwords = [token for token in document if not token in stopwords]
        removed[doc] = str(no_stopwords)
    
    return(removed)

# %%
stopwordsString = stopwords_string(tokenized)

# %%
featureDF = pd.DataFrame.from_records(stopwordsString, index=['token']).T

# %% [markdown]
# # Nutzung des TfidfVectorizers von Scikit-learn

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import pandas as pd

def tfidf_extractor(corpus, ngram_range=(1,1)):
    
    vectorizer = TfidfVectorizer(min_df=1, norm='l2', smooth_idf=True, use_idf=True, ngram_range=ngram_range)
    features = vectorizer.fit_transform(corpus)
    return vectorizer, features

tfidf_vectorizer, tfidf_features = tfidf_extractor(featureDF['token'])
print(tfidf_features[0].shape)

feature_names = tfidf_vectorizer.get_feature_names()

scikit_learn_df = pd.DataFrame(np.round(tfidf_features.todense(), 4), columns=feature_names)
# Out:
# (1, 4579)

# %%
from sklearn.cluster import KMeans
from collections import Counter
import pandas as pd
def kMeans_clustering(feature_matrix):
    
    km = KMeans(n_clusters=5, max_iter=10000)
    km.fit(feature_matrix.todense())
    clusters = km.labels_          
    return km, clusters

km_obj, clusters = kMeans_clustering(feature_matrix=tfidf_features)

cluster = pd.DataFrame(clusters)

dataframe['Cluster'] = cluster

c = Counter(clusters)
total_clusters=len(c)

cluster_details = {}  
    
ordered_centroids = km_obj.cluster_centers_.argsort()[:, ::-1]

topn_features=10

for cluster_num in range(total_clusters):
    cluster_details[cluster_num] = {}
    cluster_details[cluster_num]['cluster_num'] = cluster_num
    key_features = [feature_names[index]
                    for index
                    in ordered_centroids[cluster_num, :topn_features]]
    cluster_details[cluster_num]['key_features'] = key_features
    files = dataframe[dataframe['Cluster'] == cluster_num]['file'].values.tolist()
    cluster_details[cluster_num]['file'] = files

for cluster in cluster_details:
    print('Cluster: ' + str(cluster))
    print(' ')
    print('enthaltene Dokumente:')
    print(cluster_details.get(cluster).get('file'))
    print(' ')
    print('Keyfeatures: ')
    print(cluster_details.get(cluster).get('key_features'))
    print(' ')
    print('_'*150)
    print('_'*150)
    print(' ')
# Out:
# Cluster: 0
#
# enthaltene Dokumente:
# ['Bankenmarkt', 'Basel IV', 'Die Mailänder Börse ist in Feierlaune', 'Natixis im Gespräch', 'Schweizer Banken Die Zeiten, um an den Finanzmärkten mutig zu sein, sind erst einmal vorbei']
#
# Keyfeatures:
# ['banken', 'sparkassen', 'bank', 'investmentbanking', 'unternehmen', 'deutschland', 'vincent', 'mrd', 'piazza', 'affari']
#
# ______________________________________________________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________________________________________________
#
# Cluster: 1
#
# enthaltene Dokumente:
# ['Dramatischer Liverpool-Sieg durch spätes Eigentor', 'Jetzt wird Bayern nervös', 'Joachim Löw und die Nationalelf', 'Klopp geht all in und gewinnt', 'Zweite Bundesliga']
#
# Keyfeatures:
# ['liverpool', 'löw', 'fc', 'spiel', 'klopp', 'city', 'sieg', 'tor', 'tottenham', 'nachholspiel']
#
# ______________________________________________________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________________________________________________
#
# Cluster: 2
#
# enthaltene Dokumente:
# ['BMW setzt noch einen drauf', 'Blitz und Schatten', 'Deutschland sucht das Super-SUV', 'Mittelklasse, nur nicht beim Preis', 'Tesla im Fahrtest']
#
# Keyfeatures:
# ['bmw', 'x5', 'ps', 'model', 'x7', 'liter', 'euro', 'insignia', 'suv', 'coupé']
#
# ______________________________________________________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________________________________________________
#
# Cluster: 3
#
# enthaltene Dokumente:
# ['Der Brandbeschleuniger im Weißen Haus', 'Der Vorwurf eines unerwünschten Kusses', 'Trump, Trump und nochmals Trump', 'Was Kim kann, kann Trump auch', 'Weißes Haus rechnet mit Schließung der Grenze zu Mexiko']
#
# Keyfeatures:
# ['trump', 'biden', 'präsidenten', 'flores', 'donald', 'haus', 'grenze', 'decker', 'adorf', 'horst']
#
# ______________________________________________________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________________________________________________
#
# Cluster: 4
#
# enthaltene Dokumente:
# ['Bleibt doch noch ein bisschen', 'Hollywood-Stars präsentieren', 'Konkurrenz für Netflix', 'Ladematte AirPower', 'Lebensrettende Massnahmen für Apple TV']
#
# Keyfeatures:
# ['apple', 'konzern', 'airpower', 'netflix', 'geräte', 'tv', 'inhalte', 'geräten', 'montag', 'iphone']
#
# ______________________________________________________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________________________________________________

# %% [markdown]
# # Warum unterscheiden sich die Ergebnisse so stark?

# %% [markdown]
# ## Vergleich der Ergebnisse der Vektorisierung:
# ### Scikit-learn:

# %%
vektor = scikit_learn_df.loc[[0]]
vektorTransponiert = vektor.transpose()
vektorSorted = vektorTransponiert.sort_values(by=[0], ascending=False)
vektorSorted[:5]
# Out:
#             0
# x5     0.4450
# x7     0.2670
# bmw    0.2427
# liter  0.2238
# ps     0.1865

# %% [markdown]
# ### eigener Vectorizer:

# %%
vektor = tfidfDF.loc[['BMW setzt noch einen drauf']]
vektorTransponiert = vektor.transpose()
vektorSorted = vektorTransponiert.sort_values(by=['BMW setzt noch einen drauf'], ascending=False)
vektorSorted[:5]
# Out:
#        BMW setzt noch einen drauf
# x5                      25.257286
# x7                      15.154372
# bmw                     12.721581
# liter                   10.995489
# ps                       9.162907

# %% [markdown]
# ### -> Scikit-learn nutzt die L-2 Normalisierung (auch als Hilbertraum L2 bekannt). Daher bewegen dich die Werte zwischen 0 und 1.
# ### die Summe aller quadrierten Werte eines Dokumenten-Vektors ist hierbei genau 1.
# ### durch diese Art der Skalierung wird der Einfluss der Länge eines Dokuments weiter reduziert.
# ### Anwendung führt also zu wesentlich besseren Ergebnissen
#
# # -> die Wahl einer passenden Vektorisierung ist also maßgeblich für die Qualität einer Analyse

# %% [markdown]
# ![Abschluss](<./Grafiken/Agenda/Abschluss.jpg>)

# %% [markdown]
# # Hier fehlt noch ein Rausschmeisser
